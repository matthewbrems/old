# %%
import pandas as pd
import matplotlib.pyplot as plt

# display plots in the notebook
# %matplotlib inline

# %%
# read in the drinks data
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
url = 'https://raw.githubusercontent.com/josephofiowa/DAT8/master/data/drinks.csv'
drinks = pd.read_csv(url, header=0, names=drink_cols, na_filter=False)

# %%
#look at the first 10 rows of the data
drinks.head(10)
# Out:
#              country  beer  spirit  wine  liters continent
# 0        Afghanistan     0       0     0     0.0        AS
# 1            Albania    89     132    54     4.9        EU
# 2            Algeria    25       0    14     0.7        AF
# 3            Andorra   245     138   312    12.4        EU
# 4             Angola   217      57    45     5.9        AF
# 5  Antigua & Barbuda   102     128    45     4.9        NA
# 6          Argentina   193      25   221     8.3        SA
# 7            Armenia    21     179    11     3.8        EU
# 8          Australia   261      72   212    10.4        OC
# 9            Austria   279      75   191     9.7        EU

# %%
def eda(dataframe):
    print "missing values \n", dataframe.isnull().sum() #count how many null values are in each series
#     print "dataframe types \n", dataframe.dtypes
#     print "dataframe shape \n", dataframe.shape
#     print "dataframe describe \n", dataframe.describe()
#     for item in dataframe:
#         print item
#         print dataframe[item].nunique()

eda(drinks)
# Out:
# missing values
# country      0
# beer         0
# spirit       0
# wine         0
# liters       0
# continent    0
# dtype: int64

# %%
def eda(dataframe):
#     print "missing values \n", dataframe.isnull().sum()
    print "dataframe types \n", dataframe.dtypes #look for data types of each column
#     print "dataframe shape \n", dataframe.shape
#     print "dataframe describe \n", dataframe.describe()
#     for item in dataframe:
#         print item
#         print dataframe[item].nunique()

eda(drinks)
# Out:
# dataframe types
# country       object
# beer           int64
# spirit         int64
# wine           int64
# liters       float64
# continent     object
# dtype: object

# %%
def eda(dataframe):
#     print "missing values \n", dataframe.isnull().sum()
#     print "dataframe types \n", dataframe.dtypes
    print "dataframe shape \n", dataframe.shape #gives us the number of rows and columns
#     print "dataframe describe \n", dataframe.describe()
#     for item in dataframe:
#         print item
#         print dataframe[item].nunique()

eda(drinks)
# Out:
# dataframe shape
# (193, 6)

# %%
def eda(dataframe):
#     print "missing values \n", dataframe.isnull().sum()
#     print "dataframe types \n", dataframe.dtypes
#     print "dataframe shape \n", dataframe.shape
    print "dataframe describe \n", dataframe.describe() #summary statistics
#     for item in dataframe:
#         print item
#         print dataframe[item].nunique()

eda(drinks)
# Out:
# dataframe describe
#              beer      spirit        wine      liters
# count  193.000000  193.000000  193.000000  193.000000
# mean   106.160622   80.994819   49.450777    4.717098
# std    101.143103   88.284312   79.697598    3.773298
# min      0.000000    0.000000    0.000000    0.000000
# 25%     20.000000    4.000000    1.000000    1.300000
# 50%     76.000000   56.000000    8.000000    4.200000
# 75%    188.000000  128.000000   59.000000    7.200000
# max    376.000000  438.000000  370.000000   14.400000

# %%
def eda(dataframe):
#     print "missing values \n", dataframe.isnull().sum()
#     print "dataframe types \n", dataframe.dtypes
#     print "dataframe shape \n", dataframe.shape
#     print "dataframe describe \n", dataframe.describe()
    for item in dataframe:
        print item
        print dataframe[item].nunique() #number of unique values for each column

eda(drinks)
# Out:
# country
# 193
# beer
# 130
# spirit
# 109
# wine
# 79
# liters
# 90
# continent
# 6

# %%
# sort the beer column and mentally split it into 3 groups
drinks.beer.sort_values()
# Out:
# 0        0
# 40       0
# 79       0
# 90       0
# 97       0
# 103      0
# 106      0
# 111      0
# 128      0
# 147      0
# 13       0
# 149      0
# 107      0
# 158      0
# 46       0
# 137      1
# 38       1
# 171      1
# 73       1
# 168      2
# 123      3
# 119      5
# 116      5
# 167      5
# 104      5
# 78       5
# 53       6
# 190      6
# 86       6
# 178      6
#       ...
# 76     233
# 75     234
# 99     236
# 109    238
# 32     240
# 3      245
# 23     245
# 141    247
# 184    249
# 120    251
# 8      261
# 60     263
# 17     263
# 156    270
# 9      279
# 93     281
# 151    283
# 160    284
# 130    285
# 16     295
# 140    297
# 129    306
# 81     313
# 188    333
# 98     343
# 135    343
# 65     346
# 62     347
# 45     361
# 117    376
# Name: beer, dtype: int64

# %%
# compare with histogram
drinks.beer.plot(kind='hist', bins=3)

# %%
# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 17

# %%
# try more bins
drinks.beer.plot(kind='hist', bins=20)

# %%
# add title and labels
drinks.beer.plot(kind='hist', bins=20, title='Histogram of Beer Servings')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')

# %%
# compare with density plot (smooth version of a histogram)
drinks.beer.plot(kind='density', xlim=(0, 500))

# %%
# list available plot styles
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %%
# change to a different style
plt.style.use('ggplot')

# %%
#replot the histogram
drinks.beer.plot(kind='hist', bins=20, title='Histogram of Beer Servings')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')

# %%
# select the beer and wine columns and sort by beer
drinks[['country', 'beer', 'wine']].sort_values('beer')
# Out:
#                 country  beer  wine
# 0           Afghanistan     0     0
# 40         Cook Islands     0    74
# 79                 Iran     0     0
# 90               Kuwait     0     0
# 97                Libya     0     0
# 103            Maldives     0     0
# 106    Marshall Islands     0     0
# 111              Monaco     0     0
# 128            Pakistan     0     0
# 147          San Marino     0     0
# 13           Bangladesh     0     0
# 149        Saudi Arabia     0     0
# 107          Mauritania     0     0
# 158             Somalia     0     0
# 46          North Korea     0     0
# 137               Qatar     1     7
# 38              Comoros     1     1
# 171         Timor-Leste     1     4
# 73                Haiti     1     1
# 168          Tajikistan     2     0
# 123               Niger     3     1
# 119               Nepal     5     0
# 116             Myanmar     5     0
# 167               Syria     5    16
# 104                Mali     5     1
# 78            Indonesia     5     0
# 53                Egypt     6     1
# 190               Yemen     6     0
# 86               Jordan     6     1
# 178              Tuvalu     6     9
# ..                  ...   ...   ...
# 76              Iceland   233    78
# 75              Hungary   234   185
# 99           Luxembourg   236   271
# 109              Mexico   238     5
# 32               Canada   240   100
# 3               Andorra   245   312
# 23               Brazil   245    16
# 141  Russian Federation   247    73
# 184                 USA   249    84
# 120         Netherlands   251   190
# 8             Australia   261   212
# 60              Finland   263    97
# 17               Belize   263     8
# 156            Slovenia   270   276
# 9               Austria   279   191
# 93               Latvia   281    62
# 151              Serbia   283   127
# 160               Spain   284   112
# 130              Panama   285    18
# 16              Belgium   295   212
# 140             Romania   297   167
# 129               Palau   306    23
# 81              Ireland   313   165
# 188           Venezuela   333     3
# 98            Lithuania   343    56
# 135              Poland   343    56
# 65              Germany   346   175
# 62                Gabon   347    59
# 45       Czech Republic   361   134
# 117             Namibia   376     1
#
# [193 rows x 3 columns]

# %%
# compare with scatter plot
drinks.plot(kind='scatter', x='beer', y='wine')

# %%
# add transparency
drinks.plot(kind='scatter', x='beer', y='wine', alpha=0.3)

# %%
# vary point color by spirit servings
drinks.plot(kind='scatter', x='beer', y='wine', c='spirit', colormap='Blues')

# %%
# scatter matrix of three numerical columns
print pd.scatter_matrix(drinks[['beer', 'spirit', 'wine']])
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x124aa3bd0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x1252964d0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x125315550>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x125378c10>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x1253fbd50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x12539c5d0>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x1254ae290>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x125531490>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x125594290>]]

# %%
# increase figure size
pd.scatter_matrix(drinks[['beer', 'spirit', 'wine']], figsize=(10, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x123e61bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123064450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12325df10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12476e7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1247f1750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124857550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1248e0750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1249636d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1249d0350>]], dtype=object)

# %%
import seaborn as sns

# %%
sns.pairplot(drinks)

# %%
# count the number of countries in each continent
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# compare with bar plot
drinks.continent.value_counts().plot(kind='bar')

# %%
# calculate the mean alcohol amounts for each continent
drinks.groupby('continent').mean()
# Out:
#                  beer      spirit        wine    liters
# continent
# AF          61.471698   16.339623   16.264151  3.007547
# AS          37.045455   60.840909    9.068182  2.170455
# EU         193.777778  132.555556  142.222222  8.617778
# NA         145.434783  165.739130   24.521739  5.995652
# OC          89.687500   58.437500   35.625000  3.381250
# SA         175.083333  114.750000   62.416667  6.308333

# %%
# side-by-side bar plots
drinks.groupby('continent').mean().plot(kind='bar')

# %%
# drop the liters column
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar')

# %%
# stacked bar plots
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar', stacked=True)

# %% [markdown]
# ## Box plots

# %%
# Box Plot: show quartiles (and outliers) for one or more numerical variables
# Five-number summary:
# min = minimum value
# 25% = first quartile (Q1) = median of the lower half of the data
# 50% = second quartile (Q2) = median of the data
# 75% = third quartile (Q3) = median of the upper half of the data
# max = maximum value
# (More useful than mean and standard deviation for describing skewed distributions)
# Interquartile Range (IQR) = Q3 - Q1
# Outliers:
# below Q1 - 1.5 * IQR
# above Q3 + 1.5 * IQR

# %%
# show "five-number summary" for spirit
drinks.beer.describe()
# Out:
# count    193.000000
# mean     106.160622
# std      101.143103
# min        0.000000
# 25%       20.000000
# 50%       76.000000
# 75%      188.000000
# max      376.000000
# Name: beer, dtype: float64

# %%
# compare with box plot
drinks.beer.plot(kind='box')

# %%
# include multiple variables
drinks.drop('liters', axis=1).plot(kind='box')

# %% [markdown]
# ## Line Plot: show the trend of a numerical variable over time

# %%
url = 'https://raw.githubusercontent.com/josephofiowa/DAT8/master/data/ufo.csv'
ufo = pd.read_csv(url)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
# read in the ufo data
# url = 'https://raw.githubusercontent.com/josephofiowa/DAT8/master/data/ufo.csv'
# ufo = pd.read_csv(url)
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo['Year'] = ufo.Time.dt.year

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
# count the number of ufo reports each year (and sort by year)
ufo.Year.value_counts().sort_index()
# Out:
# 1930       2
# 1931       2
# 1933       1
# 1934       1
# 1935       1
# 1936       2
# 1937       2
# 1939       3
# 1941       2
# 1942       3
# 1943       5
# 1944       8
# 1945       9
# 1946       8
# 1947      41
# 1948       9
# 1949      19
# 1950      31
# 1951      21
# 1952      52
# 1953      36
# 1954      55
# 1955      33
# 1956      46
# 1957      78
# 1958      53
# 1959      57
# 1960      67
# 1961      50
# 1962      72
#         ...
# 1985     211
# 1986     186
# 1987     210
# 1988     232
# 1989     247
# 1990     237
# 1991     220
# 1992     245
# 1993     292
# 1994     406
# 1995    1344
# 1996     851
# 1997    1237
# 1998    1743
# 1999    2774
# 2000    2635
# 2001    2925
# 2002    2933
# 2003    3507
# 2004    3850
# 2005    3787
# 2006    3445
# 2007    4058
# 2008    4655
# 2009    4251
# 2010    4154
# 2011    5089
# 2012    7263
# 2013    7003
# 2014    5382
# Name: Year, dtype: int64

# %%
# compare with line plot
ufo.Year.value_counts().sort_index().plot()

# %%
drinks.continent.value_counts().plot()
#value count of every continent

# %% [markdown]
# # don't use a line plot when there is no logical ordering
#
# <img src="https://s-media-cache-ak0.pinimg.com/originals/26/d8/88/26d888978d61cadf1834e10c40c0516c.jpg">

# %%
#what if we're trying to show one box plot for each group

#let's take a look at a box plot of beer servings again, to begin with
drinks.beer.plot(kind='box')

# %%
# box plot of beer servings grouped by continent
drinks.boxplot(column='beer', by='continent')

# %%
# box plot of all numeric columns grouped by continent
drinks.boxplot(by='continent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127ad8990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a2ba1d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12a740d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a7b1250>]], dtype=object)

# %%
##histograms: what if we're trying to show one histogram for each group

# reminder: histogram of beer servings
drinks.beer.plot(kind='hist')

# %%
# histogram of beer servings grouped by continent
drinks.hist(column='beer', by='continent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12a206990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b1bb150>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12b22fed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b2a9250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12b329a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b38f590>]], dtype=object)

# %%
# share the x axes
drinks.hist(column='beer', by='continent', sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12b646fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a028f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12b8b6650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b91ed50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12b9ad290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b94ce50>]], dtype=object)

# %%
# share the x and y axes
drinks.hist(column='beer', by='continent', sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12b651150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12bff0a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12c0706d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c0d4b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12c157910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c0f8790>]], dtype=object)

# %%
# change the layout
drinks.hist(column='beer', by='continent', sharex=True, layout=(2, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12c32a8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c835ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c8b3d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12c9252d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c9a6210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12c93cc10>]], dtype=object)

# %%
# what if you're creating a plot 
#adding axes
# AND saving a plot to a file
drinks.beer.plot(kind='hist', bins=20, title='Histogram of Beer Servings')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.savefig('beer_histogram.png')

# %% [markdown]
# <img src='https://s-media-cache-ak0.pinimg.com/originals/c3/0b/9b/c30b9bafd87748c65b270b621f8985f0.jpg'>
