# %% [markdown]
# # Webscraping 2.0
#
# Joseph Nelson, DC
#
# In today's codealong, I'll walkthrough how to build a scraper using urllib and BeautifulSoup. We'll discover the problems we discussed in the lesson readme associated with doing so, and we'll remedy this problem using a headless browser called Selenium.

# %% [markdown]
# For starter's we're going to be scraping OpenTable's DC listings. We're interested in knowing the restaurant's **name, location, price, and how many people booked it today.**
#
# OpenTable provides all of this information on this given page: http://www.opentable.com/washington-dc-restaurant-listings
#
# Let's inspect the elements of this page to assure we can find each of the bits of information in which we're interested.
# >Class proceeds to do exactly that ^
#
# We'll then build our scraper:

# %%
# import our necessary first packages
from bs4 import BeautifulSoup
import urllib

# %%
# set the url we want to visit
url = "http://www.opentable.com/washington-dc-restaurant-listings"

# visit that url, and grab the html of said page
html = urllib.urlopen(url).read()

# %% [markdown]
# At this point, what is in html?

# %%
html
# Out:
# '          <!DOCTYPE html><html lang="en"><head><meta charset="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=9; IE=8; IE=7; IE=EDGE"/> <title>Washington, D.C. Area Restaurants List | OpenTable</title>  <meta  name="description" content="Find Washington, D.C. Area restaurants. Search by location, cuisine, or price to refine restaurant results in the Washington, D.C. Area area." > </meta>  <meta  name="robots" content="noindex" > </meta>    <link rel="shortcut icon" href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon.ico" type="image/x-icon"/><link rel="icon" href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-16.png" sizes="16x16"/><link rel="icon" href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-32.png" sizes="32x32"/><link rel="icon" href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-48.png" sizes="48x48"/><link rel="icon" href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-64.png" sizes="64x64"/><link rel="icon" href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-128.png" sizes="128x128"/><link rel="apple-touch-icon-precomposed" sizes="152x152" href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-152x152-precomposed.png"/><link rel="apple-touch-icon-precomposed" sizes="144x144" href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-144x144-precomposed.png"/><link rel="apple-touch-icon-precomposed" sizes="120x120" href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-120x120-precomposed.png"/><link rel="apple-touch-icon-precomposed" sizes="114x114" href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-114x114-precomposed.png"/><link rel="apple-touch-icon-precomposed" sizes="76x76" href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-76x76-precomposed.png"/><link rel="apple-touch-icon-precomposed" sizes="72x72" href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-72x72-precomposed.png"/><link rel="apple-touch-icon-precomposed" href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-144x144-precomposed.png"/><meta property="og:image" content="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-152x152-precomposed.png"/><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["favicon"]="1.0.4";</script><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/> <link rel="stylesheet" href="//media.otstatic.com/search-result-node/css/bundle_redesign_search.8da4ca30.css"/><!--[if lte IE 8]><link rel="stylesheet" href="//media.otstatic.com/search-result-node/css/bundle_redesign_search_ie8.9d2e13e7.css" /> <![endif]  --> <script>window.OT = window.OT || {};\nwindow.OT.SRS = {\n  abTestingAnalytics: {"account":"2d65a94551a4a1caddd5a825a88698a89e19f2d5","hostname":"ac.opentable.com"},\n  ocUrl: window.location.protocol + \'//oc-registry.opentable.com/v2/\',\n  lang: "en"\n};\n</script><!--[if lte IE 8]> <script src="//components.otstatic.com/components/js-head/1.0.58/min/ie8_compat.js"></script> <![endif]-->\n<!--[if IE 9]> <script src="//components.otstatic.com/components/js-head/1.0.58/min/ie9_compat.js"></script> <![endif]--><script src="//components.otstatic.com/components/js-head/1.0.58/min/bundle_head.js" crossorigin="anonymous"></script><!--[if lte IE 9]> <script src="//components.otstatic.com/components/js-head/1.0.58/min/ie_jquery.js"></script> <![endif]--><script>window.optimizely = window.optimizely || [];\noptimizely.push([\'setDimensionValue\', \'Language\', \'en\']);</script><script src="//cdn.optimizely.com/js/174495938.js"></script><script type="text/javascript" src="//7202552.collect.igodigital.com/collect.js"></script><script>try{ Typekit.load(); window.TypekitLoaded = true;  ...

# %%
# we need to convert this into a soup object
soup = BeautifulSoup(html, 'html.parser', from_encoding="utf-8")

# %% [markdown]
# Let's first find each restaurant name listed on the page we've loaded. How do we find the page location of the restaurant? (Psst: we need to know where in the **html** the restaurant element is housed)
#
# See if you can find the restaurant name on the page. Keep in mind there are many restaurants loaded on the page.

# %%
# print the restaurant names
print soup.find_all('span', {'class': 'rest-row-name-text'})
# Out:
# [<span class="rest-row-name-text">Voltaggio Brothers Steak House - MGM National Harbor</span>, <span class="rest-row-name-text">barmini by José Andrés</span>, <span class="rest-row-name-text">Fish by Jose Andres - MGM National Harbor</span>, <span class="rest-row-name-text">Le Diplomate</span>, <span class="rest-row-name-text">Rasika</span>, <span class="rest-row-name-text">Kinship</span>, <span class="rest-row-name-text">Rasika West End</span>, <span class="rest-row-name-text">Sushi Taro</span>, <span class="rest-row-name-text">The Goodstone Inn &amp; Estate Restaurant</span>, <span class="rest-row-name-text">Elizabeth's Gone Raw</span>, <span class="rest-row-name-text">Iron Gate Patio &amp; Garden</span>, <span class="rest-row-name-text">Marcus - MGM National Harbor</span>, <span class="rest-row-name-text">Roof Terrace Restaurant &amp; Bar</span>, <span class="rest-row-name-text">RPM Italian - DC</span>, <span class="rest-row-name-text">Blue Duck Tavern</span>, <span class="rest-row-name-text">Doi Moi</span>, <span class="rest-row-name-text">Field &amp; Main</span>, <span class="rest-row-name-text">Hazel</span>, <span class="rest-row-name-text">Vasili's Kitchen</span>, <span class="rest-row-name-text">Uncle Julio's - Gainesville</span>, <span class="rest-row-name-text">Founding Farmers - DC</span>, <span class="rest-row-name-text">Ambar</span>, <span class="rest-row-name-text">Joe's Seafood, Prime Steak &amp; Stone Crab - Washington DC</span>, <span class="rest-row-name-text">Nostos Restaurant</span>, <span class="rest-row-name-text">Old Ebbitt Grill</span>, <span class="rest-row-name-text">Ambar - Arlington</span>, <span class="rest-row-name-text">Farmers &amp; Distillers</span>, <span class="rest-row-name-text">Uncle Julio's - Loudoun</span>, <span class="rest-row-name-text">Restaurant Eve</span>, <span class="rest-row-name-text">Ruth's Chris Steak House - Gaithersburg</span>, <span class="rest-row-name-text">Landini Brothers</span>, <span class="rest-row-name-text">Bombay Club</span>, <span class="rest-row-name-text">TAP Sports Bar - MGM National Harbor</span>, <span class="rest-row-name-text">The Melting Pot - Reston</span>, <span class="rest-row-name-text">Ted's Bulletin - 14th Street</span>, <span class="rest-row-name-text">Texas de Brazil - Fairfax</span>, <span class="rest-row-name-text">Farmers Fishers Bakers</span>, <span class="rest-row-name-text">Plume at the Jefferson Hotel</span>, <span class="rest-row-name-text">Uncle Julio's - Bethesda Row</span>, <span class="rest-row-name-text">Plan B Burger Bar - Washington DC</span>, <span class="rest-row-name-text">Ginger - MGM National Harbor</span>, <span class="rest-row-name-text">Uncle Julio's - Gaithersburg</span>, <span class="rest-row-name-text">Zaytinya</span>, <span class="rest-row-name-text">The Melting Pot - Arlington VA</span>, <span class="rest-row-name-text">Eddie V's - Tysons Corner</span>, <span class="rest-row-name-text">The Melting Pot - Gaithersburg</span>, <span class="rest-row-name-text">Boqueria - DC</span>, <span class="rest-row-name-text">1789 Restaurant</span>, <span class="rest-row-name-text">Filomena Ristorante</span>, <span class="rest-row-name-text">Uncle Julio's - Reston Town Center</span>, <span class="rest-row-name-text">Estadio</span>, <span class="rest-row-name-text">Harrimans Virginia Piedmont Grill</span>, <span class="rest-row-name-text">TenPenh - Tysons</span>, <span class="rest-row-name-text">The Wine House</span>, <span class="rest-row-name-text">Bourbon Steak - Four Seasons Washington DC</span>, <span class="rest-row-name-text">Founding Farmers - Tysons</span>, <span class="rest-row-name-text">Succotash Restaurant</span>, <span class="rest-row-name-text">Empress Lounge at the Mandarin Oriental - DC</span>, <span class="rest-row-name-text">Chez Billy Sud</span>, <span class="rest-row-name-text">Paladar Latin Kitchen and Rum Bar</span>, <span class="rest-row-name-text">Ruth's Chris Steak House - Bethesda</span>, <span class="rest-ro ...

# %% [markdown]
# Now that we can find each element, let's think how we can loop through them all one-by-one. In the following cell, print out the name (and **only** the clean name, not the rest of the html) of each restaurant.

# %%
# for each element you find, print out the restaurant name
for entry in soup.find_all('span', {'class': 'rest-row-name-text'}):
    print entry.renderContents()
# Out:
# Voltaggio Brothers Steak House - MGM National Harbor
# barmini by José Andrés
# Fish by Jose Andres - MGM National Harbor
# Le Diplomate
# Rasika
# Kinship
# Rasika West End
# Sushi Taro
# The Goodstone Inn &amp; Estate Restaurant
# Elizabeth's Gone Raw
# Iron Gate Patio &amp; Garden
# Marcus - MGM National Harbor
# Roof Terrace Restaurant &amp; Bar
# RPM Italian - DC
# Blue Duck Tavern
# Doi Moi
# Field &amp; Main
# Hazel
# Vasili's Kitchen
# Uncle Julio's - Gainesville
# Founding Farmers - DC
# Ambar
# Joe's Seafood, Prime Steak &amp; Stone Crab - Washington DC
# Nostos Restaurant
# Old Ebbitt Grill
# Ambar - Arlington
# Farmers &amp; Distillers
# Uncle Julio's - Loudoun
# Restaurant Eve
# Ruth's Chris Steak House - Gaithersburg
# Landini Brothers
# Bombay Club
# TAP Sports Bar - MGM National Harbor
# The Melting Pot - Reston
# Ted's Bulletin - 14th Street
# Texas de Brazil - Fairfax
# Farmers Fishers Bakers
# Plume at the Jefferson Hotel
# Uncle Julio's - Bethesda Row
# Plan B Burger Bar - Washington DC
# Ginger - MGM National Harbor
# Uncle Julio's - Gaithersburg
# Zaytinya
# The Melting Pot - Arlington VA
# Eddie V's - Tysons Corner
# The Melting Pot - Gaithersburg
# Boqueria - DC
# 1789 Restaurant
# Filomena Ristorante
# Uncle Julio's - Reston Town Center
# Estadio
# Harrimans Virginia Piedmont Grill
# TenPenh - Tysons
# The Wine House
# Bourbon Steak - Four Seasons Washington DC
# Founding Farmers - Tysons
# Succotash Restaurant
# Empress Lounge at the Mandarin Oriental - DC
# Chez Billy Sud
# Paladar Latin Kitchen and Rum Bar
# Ruth's Chris Steak House - Bethesda
# Mon Ami Gabi - Bethesda
# Claire's at the Depot
# Momofuku CCDC
# Sushi Ogawa
# Mykonos Grill
# Jacques' Brasserie at L'Auberge Chez Francois
# Vermilion - Alexandria
# Firestone's
# Kapnos Kouzina
# Ray's The Steaks
# Medium Rare - Cleveland Park
# The Inn at Little Washington
# Chart House Restaurant - Alexandria
# El Centro D.F. on 14th Street
# Cooper's Hawk Winery &amp; Restaurant - Ashburn
# Capitol City Brewing Company - Downtown
# Seasons Restaurant - Four Seasons Washington DC
# VOLT
# Trummer's on Main
# Marriott Westfields - Fairfax Dining Room
# True Food Kitchen - Fairfax
# Chaplin
# L'Auberge Chez Francois
# The Capital Grille - Washington DC
# The Arsenal at Bluejacket
# El Centro D.F. - Georgetown
# Oyamel
# SoBe Restaurant &amp; Lounge
# Clyde's of Chevy Chase
# BlackSalt
# Copper Canyon Grill - Glenarden
# Wildfire - Tysons Galleria
# Maggiano's - Tyson's Corner
# Monocacy Crossing
# Uncle Julio's - Fairfax Corner
# The Restaurant at Patowmack Farm
# Earls Kitchen + Bar - Tysons Corner
# Founding Farmers - Montgomery County
# Acqua Al 2

# %% [markdown]
# Great!
#
# Can you repeat that process for finding the location? For example, barmini by Jose Andres is in the location listed as "Penn Quarter" in our search results.

# %%
# first, see if you can identify the location for all elements -- print it out
print soup.find_all('span', {'class': 'rest-row-meta--location rest-row-meta-text'})
# Out:
# [<span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>, <span class="rest-row-meta--location rest-row-meta-text">Penn Quarter</span>, <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>, <span class="rest-row-meta--location rest-row-meta-text">Logan Circle</span>, <span class="rest-row-meta--location rest-row-meta-text">Penn Quarter</span>, <span class="rest-row-meta--location rest-row-meta-text">Mt. Vernon Square</span>, <span class="rest-row-meta--location rest-row-meta-text">West End</span>, <span class="rest-row-meta--location rest-row-meta-text">Dupont Circle</span>, <span class="rest-row-meta--location rest-row-meta-text">Middleburg</span>, <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>, <span class="rest-row-meta--location rest-row-meta-text">Dupont Circle</span>, <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>, <span class="rest-row-meta--location rest-row-meta-text">Foggy Bottom</span>, <span class="rest-row-meta--location rest-row-meta-text">Mt. Vernon Square</span>, <span class="rest-row-meta--location rest-row-meta-text">West End</span>, <span class="rest-row-meta--location rest-row-meta-text">Logan Circle</span>, <span class="rest-row-meta--location rest-row-meta-text">The Plains</span>, <span class="rest-row-meta--location rest-row-meta-text">Shaw</span>, <span class="rest-row-meta--location rest-row-meta-text">Gaithersburg</span>, <span class="rest-row-meta--location rest-row-meta-text">Gainesville</span>, <span class="rest-row-meta--location rest-row-meta-text">Foggy Bottom</span>, <span class="rest-row-meta--location rest-row-meta-text">Capitol Hill</span>, <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>, <span class="rest-row-meta--location rest-row-meta-text">Vienna</span>, <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>, <span class="rest-row-meta--location rest-row-meta-text">Arlington</span>, <span class="rest-row-meta--location rest-row-meta-text">Mt. Vernon Square</span>, <span class="rest-row-meta--location rest-row-meta-text">Ashburn</span>, <span class="rest-row-meta--location rest-row-meta-text">Old Town Alexandria</span>, <span class="rest-row-meta--location rest-row-meta-text">Gaithersburg</span>, <span class="rest-row-meta--location rest-row-meta-text">Alexandria</span>, <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>, <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>, <span class="rest-row-meta--location rest-row-meta-text">Reston</span>, <span class="rest-row-meta--location rest-row-meta-text">Logan Circle</span>, <span class="rest-row-meta--location rest-row-meta-text">Fairfax</span>, <span class="rest-row-meta--location rest-row-meta-text">Georgetown</span>, <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>, <span class="rest-row-meta--location rest-row-meta-text">Bethesda / Chevy Chase</span>, <span class="rest-row-meta--location rest-row-meta-text">Washington</span>, <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>, <span class="rest-row-meta--location rest-row-meta-text">Gaithersburg</span>, <span class="rest-row-meta--location rest-row-meta-text">Penn Quarter</span>, <span class="rest-row-meta--location rest-row-meta-text">Arlington</span>, <span class="rest-row-meta--location rest-row-meta-text">Tysons Corner / McLean</span>, <span class="rest-row-meta--location rest-row-meta-text">Gaithersburg</span>, <span class="rest-row-meta--location rest-row-meta-text">Dupont Circle</span>, <span class="rest-row-meta--location rest-row-meta-text">Georgetown</span>, <span class="rest-row-meta--location rest-row-meta-text">Georgetown</span>, <span class="rest-row-meta--location rest-row-meta-text">Reston</span>, <span class="rest-row-meta--location rest-row-meta-text">Logan Circle</span>, <span class="rest-row-meta--location rest-row-meta-text">Middleburg</span>,  ...

# %%
# now print out EACH location for the restaurants
for entry in soup.find_all('span', {'class': 'rest-row-meta--location rest-row-meta-text'}):
    print entry.renderContents()
# Out:
# Oxon Hill
# Penn Quarter
# Oxon Hill
# Logan Circle
# Penn Quarter
# Mt. Vernon Square
# West End
# Dupont Circle
# Middleburg
# Downtown
# Dupont Circle
# Oxon Hill
# Foggy Bottom
# Mt. Vernon Square
# West End
# Logan Circle
# The Plains
# Shaw
# Gaithersburg
# Gainesville
# Foggy Bottom
# Capitol Hill
# Downtown
# Vienna
# Downtown
# Arlington
# Mt. Vernon Square
# Ashburn
# Old Town Alexandria
# Gaithersburg
# Alexandria
# Downtown
# Oxon Hill
# Reston
# Logan Circle
# Fairfax
# Georgetown
# Downtown
# Bethesda / Chevy Chase
# Washington
# Oxon Hill
# Gaithersburg
# Penn Quarter
# Arlington
# Tysons Corner / McLean
# Gaithersburg
# Dupont Circle
# Georgetown
# Georgetown
# Reston
# Logan Circle
# Middleburg
# Tysons Corner / McLean
# Fairfax
# Georgetown
# Tysons Corner / McLean
# National Harbor
# Downtown
# Georgetown
# Gaithersburg
# Bethesda / Chevy Chase
# Bethesda / Chevy Chase
# Warrenton
# Mount Vernon
# Dupont Circle
# Rockville
# Great Falls
# Alexandria
# Frederick
# Bethesda / Chevy Chase
# Arlington
# Cleveland Park
# Washington
# Alexandria
# Downtown
# Ashburn
# Downtown
# Georgetown
# Frederick
# Clifton
# Chantilly
# Fairfax
# Shaw
# Great Falls
# Capitol Hill
# Navy Yard
# Georgetown
# Penn Quarter
# Lanham
# Friendship Heights
# Palisades Northwest
# Lanham
# Tysons Corner / McLean
# Tysons Corner / McLean
# Frederick
# Fairfax
# Lovettsville
# Tysons Corner / McLean
# Rockville
# Capitol Hill

# %% [markdown]
# Ok, we've figured out the restaurant name and location. Now we need to grab the price (number of dollar signs on a scale of one to four) for each restaurant. We'll follow the same process.

# %%
# print out all prices
print soup.find_all('div', {'class': 'rest-row-pricing'})
# Out:
# [<div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $      </i>   $    $      </div>, <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div>, <div class="rest-row-pricing"> <i>  $    $    ...

# %%
# print out EACH number of dollar signs per restaurant
# this one is trickier to eliminate the html. Hint: try a nested find
for entry in soup.find_all('div', {'class': 'rest-row-pricing'}):
    print entry.find('i').renderContents()
# Out:
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $

# %% [markdown]
# That looks great, but what if I wanted just the number of dollar signs per restaurant? Can you figure out a way to simply print out the number of dollar signs per restaurant listed?

# %%
# print the number of dollars signs per restaurant
for entry in soup.find_all('div', {'class': 'rest-row-pricing'}):
    price = entry.find('i').renderContents()
    print price.count('$')
# Out:
# 4
# 3
# 4
# 3
# 3
# 4
# 3
# 4
# 4
# 4
# 3
# 4
# 4
# 3
# 3
# 2
# 2
# 3
# 3
# 2
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 4
# 3
# 3
# 3
# 2
# 3
# 2
# 3
# 2
# 4
# 2
# 2
# 3
# 2
# 3
# 3
# 3
# 3
# 3
# 4
# 3
# 2
# 2
# 3
# 2
# 3
# 3
# 2
# 2
# 3
# 2
# 2
# 3
# 3
# 2
# 3
# 4
# 2
# 2
# 3
# 3
# 3
# 2
# 2
# 4
# 3
# 2
# 2
# 2
# 4
# 4
# 2
# 4
# 2
# 2
# 4
# 4
# 2
# 2
# 2
# 3
# 2
# 3
# 3
# 2
# 2
# 3
# 2
# 4
# 2
# 2
# 3

# %% [markdown]
# Phew, nice work.
#
# One more, right? We only need to find the number times a restaurant was booked. In the next cell, print out all objects that contain the number of times the restaurant was booked.

# %%
# print out all objects that contain the number of times the restaurant was booked
print soup.find_all('span', {'class': 'tadpole'})
# Out:
# []

# %% [markdown]
# That's weird -- an empty set. Did we find the wrong element? What's going on here? Discuss.
#
# How can we debug this? Any ideas?

# %%
# let's first try printing out all 'span' class objects
for entry in soup.find_all('span'):
         print entry
# Out:
# <span class="menu-list-link-meta">2009</span>
# <span class="menu-list-link-meta">726</span>
# <span class="menu-list-link-meta">837</span>
# <span class="menu-list-link-meta">446</span>
# <span itemprop="name">Home</span>
# <span itemprop="item"><span itemprop="name">United States</span></span>
# <span itemprop="name">United States</span>
# <span itemprop="name">Washington, D.C. Area</span>
# <span class="filters" data-target="Regions-filter-menu"><span class="location-icon filter-icon"></span> <span class="filter-list-title">Regions</span> <span class="filter-count"></span></span>
# <span class="location-icon filter-icon"></span>
# <span class="filter-list-title">Regions</span>
# <span class="filter-count"></span>
# <span title="All Locations">All Locations</span>
# <span title="District of Columbia"> District of Columbia </span>
# <span title="Maryland - DC Suburbs"> Maryland - DC Suburbs </span>
# <span title="Virginia - DC Suburbs"> Virginia - DC Suburbs </span>
# <span class="filters" data-target="Cuisines-filter-menu"><span class="cuisine-icon filter-icon"></span> <span class="filter-list-title">Cuisine</span> <span class="filter-count"></span></span>
# <span class="cuisine-icon filter-icon"></span>
# <span class="filter-list-title">Cuisine</span>
# <span class="filter-count"></span>
# <span title="All Cuisines">All Cuisines</span>
# <span title="Afghan"> Afghan </span>
# <span title="African"> African </span>
# <span title="Afternoon Tea"> Afternoon Tea </span>
# <span title="American"> American </span>
# <span title="Argentinean"> Argentinean </span>
# <span title="Asian"> Asian </span>
# <span title="Australian"> Australian </span>
# <span title="Austrian"> Austrian </span>
# <span title="Balkan style"> Balkan style </span>
# <span title="Bar / Lounge / Bottle Service"> Bar / Lounge / Bottle Service </span>
# <span title="Barbecue"> Barbecue </span>
# <span title="Basque"> Basque </span>
# <span title="Bavarian"> Bavarian </span>
# <span title="Beer Garden"> Beer Garden </span>
# <span title="Belgian"> Belgian </span>
# <span title="Bistro"> Bistro </span>
# <span title="Brazilian"> Brazilian </span>
# <span title="Brazilian Steakhouse"> Brazilian Steakhouse </span>
# <span title="Breakfast"> Breakfast </span>
# <span title="Brewery"> Brewery </span>
# <span title="British"> British </span>
# <span title="Burgers"> Burgers </span>
# <span title="Café"> Café </span>
# <span title="Cajun"> Cajun </span>
# <span title="Californian"> Californian </span>
# <span title="Caribbean"> Caribbean </span>
# <span title="Chinese"> Chinese </span>
# <span title="Comfort Food"> Comfort Food </span>
# <span title="Contemporary American"> Contemporary American </span>
# <span title="Contemporary Asian"> Contemporary Asian </span>
# <span title="Contemporary European"> Contemporary European </span>
# <span title="Contemporary French"> Contemporary French </span>
# <span title="Contemporary French / American"> Contemporary French / American </span>
# <span title="Contemporary Indian"> Contemporary Indian </span>
# <span title="Contemporary Italian"> Contemporary Italian </span>
# <span title="Contemporary Korean"> Contemporary Korean </span>
# <span title="Contemporary Mexican"> Contemporary Mexican </span>
# <span title="Contemporary Southern"> Contemporary Southern </span>
# <span title="Continental"> Continental </span>
# <span title="Creative Japanese"> Creative Japanese </span>
# <span title="Creole"> Creole </span>
# <span title="Creole / Cajun / Southern"> Creole / Cajun / Southern </span>
# <span title="Creperie"> Creperie </span>
# <span title="Cuban"> Cuban </span>
# <span title="Dessert"> Dessert </span>
# <span title="Dim Sum"> Dim Sum </span>
# <span title="Dining Bar"> Dining Bar </span>
# <span title="Dinner Cruise"> Dinner Cruise </span>
# <span title="Eastern European"> Eastern European </span>
# <span title="Egyptian"> Egyptian </span>
# <span title="English"> English </span>
# <span title="Ethiopian"> Ethiopian </span>
# <span title="European"> European </span>
# <span title="Farm-to-table"> Farm-to-table </span>
# <span title="Fine cuts"> Fine cuts </span>
# <span title="Fish"> Fish </span>
# <span title="Fondue"> Fondue </span>
# <span title="French"> French </span>
# <span title="French American"> French American </span>
# <span title="Fusion / Eclectic"> Fusion / Eclectic </span>
# <span title="Gastro Pub"> Gastro Pub </span>
# <span title="German"> German </span>
# <span title="Global, International"> Global, International </span>
# <span title="Greek"> Greek </span>
# <span title="Grill"> Grill </span>
# <span title="Halal"> Halal </span>
# <span title="Hawaiian"> Hawaiian </span>
# <span title="Home cooking"> Home cooking </span>
# <span title="Indian"> Indian </span>
# <span title="International"> International </span>
# <span title="Irish"> Irish </span>
# <span title="Italian"> Italian </span>
# <span title="Japanese"> Japanese </span>
# <span title="Jugoslavian"> Jugoslavian </span>
# <span title="Korean"> Korean </span>
# <span title="Kosher"> Kosher </span>
# <span title="Latin / Spanish"> Latin / Spanish </span>
# <span title="Latin American"> Latin American </span>
# <span title="Lebanese"> Lebanese </span>
# <span title="Lounge"> Lounge </span>
# <span title="Low Country"> Low Country </span>
# <span title="Mediterranean"> Mediterranean </span>
# <span title="Mexican"> Mexican </span>
# <span title="Mexican / Southwestern"> Mexican / Southwestern </span>
# <span title="Middle Eastern"> Middle Eastern </span>
# <span title="Modern European"> Modern European </span>
# <span title="Modern Tuscan"> Modern Tuscan </span>
# <span title="Moroccan"> Moroccan </span>
# <span title="Nepalese"> Nepalese </span>
# <span title="Organic"> Organic </span>
# <span title="Oyster Bar"> Oyster Bar </span>
# <span title="Pakistani"> Pakistani </span>
# <span title="Pan-Asian"> Pan-Asian </span>
# <span title="Persian"> Persian </span>
# <span title="Peruvian"> Peruvian </span>
# <span title="Pizzeria"> Pizzeria </span>
# <span title="Polish"> Polish </span>
# <span title="Portuguese"> Portuguese </span>
# <span title="Prime Rib"> Prime Rib </span>
# <span title="Provencal"> Provencal </span>
# <span title="Puerto Rican"> Puerto Rican </span>
# <span title="Russian"> Russian </span>
# <span title="Scandinavian"> Scandinavian </span>
# <span title="Seafood"> Seafood </span>
# <span title="Shabu-shabu"> Shabu-shabu </span>
# <span title="South American"> South American </span>
# <span title="Southeast Asian"> Southeast Asian </span>
# <span title="Southern"> Southern </span>
# <span title="Southwest"> Southwest </span>
# <span title="Spanish"> Spanish </span>
# <span title="Steak"> Steak </span>
# <span title="Steakhouse"> Steakhouse </span>
# <span title="Sushi"> Sushi </span>
# <span title="Tapas / Small Plates"> Tapas / Small Plates </span>
# <span title="Tex-Mex"> Tex-Mex </span>
# <span title="Thai"> Thai </span>
# <span title="Traditional French"> Traditional French </span>
# <span title="Turkish"> Turkish </span>
# <span title="Vegan"> Vegan </span>
# <span title="Vegetarian"> Vegetarian </span>
# <span title="Vegetarian / Vegan"> Vegetarian / Vegan </span>
# <span title="Venezuelan"> Venezuelan </span>
# <span title="Vietnamese"> Vietnamese </span>
# <span title="Wild Game"> Wild Game </span>
# <span title="Wine Bar"> Wine Bar </span>
# <span title="Yakitori"> Yakitori </span>
# <span class="see-filters" data-menu="Cuisines-filter-menu"><span class="with-arrow text-arrow-down">See all</span> <span class="with-arrow text-arrow-up">See less</span></span>
# <span class="with-arrow text-arrow-down">See all</span>
# <span class="with-arrow text-arrow-up">See less</span>
# <span class="filters" data-target="PriceBands-filter-menu"><span class="payment-icon filter-icon"></span> <span class="filter-list-title">Price</span> <span class="filter-count"></span></span>
# <span class="payment-icon filter-icon"></span>
# <span class="filter-list-title">Price</span>
# <span class="filter-count"></span>
# <span title="All Prices">All Prices</span>
# <span title="$$ ($30 and under)"> $$ ($30 and under) </span>
# <span title="$$$ ($31 to $50)"> $$$ ($31 to $50) </span>
# <span title="$$$$ ($50 and over)"> $$$$ ($50 and over) </span>
# <span class="filters" data-target="Tags-filter-menu"><span class="top-rated-icon filter-icon"></span> <span class="filter-list-title">Top Rated</span> <span class="filter-count"></span></span>
# <span class="top-rated-icon filter-icon"></span>
# <span class="filter-list-title">Top Rated</span>
# <span class="filter-count"></span>
# <span title="All Top Rated">All Top Rated</span>
# <span title="Authentic"> Authentic </span>
# <span title="Bar Seating"> Bar Seating </span>
# <span title="Byob"> Byob </span>
# <span title="Casual"> Casual </span>
# <span title="Charming"> Charming </span>
# <span title="Comfort Food"> Comfort Food </span>
# <span title="Convenient"> Convenient </span>
# <span title="Couples"> Couples </span>
# <span title="Cozy"> Cozy </span>
# <span title="Creative Cuisine"> Creative Cuisine </span>
# <span title="Dancing"> Dancing </span>
# <span title="Dim Lighting"> Dim Lighting </span>
# <span title="Downstairs"> Downstairs </span>
# <span title="Earn Bonus Points"> Earn Bonus Points </span>
# <span title="Eater's Essential Restaurants"> Eater's Essential Restaurants </span>
# <span title="Families"> Families </span>
# <span title="Family Style"> Family Style </span>
# <span title="Fireplace"> Fireplace </span>
# <span title="Fit for Foodies"> Fit for Foodies </span>
# <span title="Formal"> Formal </span>
# <span title="Fried Food"> Fried Food </span>
# <span title="Fun"> Fun </span>
# <span title="Gluten Free Options"> Gluten Free Options </span>
# <span title="Good for Anniversaries"> Good for Anniversaries </span>
# <span title="Good for Birthdays"> Good for Birthdays </span>
# <span title="Good for Groups"> Good for Groups </span>
# <span title="Good for a Business Meeting"> Good for a Business Meeting </span>
# <span title="Good for a Date"> Good for a Date </span>
# <span title="Great Beer"> Great Beer </span>
# <span title="Great Service"> Great Service </span>
# <span title="Great for Brunch"> Great for Brunch </span>
# <span title="Great for Lunch"> Great for Lunch </span>
# <span title="Handcrafted Cocktails"> Handcrafted Cocktails </span>
# <span title="Happy Hour"> Happy Hour </span>
# <span title="Healthy"> Healthy </span>
# <span title="Historic"> Historic </span>
# <span title="Hot Spot"> Hot Spot </span>
# <span title="Kid-friendly"> Kid-friendly </span>
# <span title="Limited Parking"> Limited Parking </span>
# <span title="Live Music"> Live Music </span>
# <span title="Local Ingredients"> Local Ingredients </span>
# <span title="Modern Decor"> Modern Decor </span>
# <span title="Molecular Gastronomy"> Molecular Gastronomy </span>
# <span title="Mother's Day"> Mother's Day </span>
# <span title="Neighborhood Gem"> Neighborhood Gem </span>
# <span title="New &amp; Hot"> New &amp; Hot </span>
# <span title="Notable Wine List"> Notable Wine List </span>
# <span title="Open Kitchen"> Open Kitchen </span>
# <span title="OpenTable Picks Spring 2016"> OpenTable Picks Spring 2016 </span>
# <span title="Organic"> Organic </span>
# <span title="Outdoor Seating"> Outdoor Seating </span>
# <span title="Paleo Friendly"> Paleo Friendly </span>
# <span title="People Watching"> People Watching </span>
# <span title="Pets Allowed"> Pets Allowed </span>
# <span title="Private Room"> Private Room </span>
# <span title="Prix Fixe Menu"> Prix Fixe Menu </span>
# <span title="Quiet Conversation"> Quiet Conversation </span>
# <span title="Romantic"> Romantic </span>
# <span title="Scenic View"> Scenic View </span>
# <span title="Seasonal"> Seasonal </span>
# <span title="Speakeasy"> Speakeasy </span>
# <span title="Special Occasion"> Special Occasion </span>
# <span title="Spicy"> Spicy </span>
# <span title="TV"> TV </span>
# <span title="Tapas"> Tapas </span>
# <span title="Tasting Flight"> Tasting Flight </span>
# <span title="Tasting Menu"> Tasting Menu </span>
# <span title="Tourists"> Tourists </span>
# <span title="Upscale"> Upscale </span>
# <span title="Valet"> Valet </span>
# <span title="Vegan"> Vegan </span>
# <span title="Vegetarian"> Vegetarian </span>
# <span title="Vibrant Bar Scene"> Vibrant Bar Scene </span>
# <span title="Waterfront"> Waterfront </span>
# <span title="Wood Oven"> Wood Oven </span>
# <span title="Worth the Drive"> Worth the Drive </span>
# <span class="see-filters" data-menu="Tags-filter-menu"><span class="with-arrow text-arrow-down">See all</span> <span class="with-arrow text-arrow-up">See less</span></span>
# <span class="with-arrow text-arrow-down">See all</span>
# <span class="with-arrow text-arrow-up">See less</span>
# <span class="filters" data-target="Times-filter-menu"><span class="time-icon filter-icon"></span> <span class="filter-list-title">Time</span> <span class="filter-count"></span></span>
# <span class="time-icon filter-icon"></span>
# <span class="filter-list-title">Time</span>
# <span class="filter-count"></span>
# <span title="{0} Only"> 7:00 pm Only </span>
# <span title="1,000 Point Times"> 1,000 Point Times </span>
# <span class="filters icon-as-button button--no-hover" data-target="sort-filter-menu" id="filter-button-toggle" title="Sort"><i class="icon-sort"></i> <span class="current-sort-order">Sort</span></span>
# <span class="current-sort-order">Sort</span>
# <span>Most Popular</span>
# <span>A-Z</span>
# <span>Highest Rated</span>
# <span class="listIndex">1.</span>
# <span class="rest-row-name-text">Voltaggio Brothers Steak House - MGM National Harbor</span>
# <span class="new-restaurant-tag">New</span>
# <span class="star-rating-text">(11)</span>
# <span class="star-rating-text--review-text">11 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">92% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">92% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Steakhouse</span>
# <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>
# <span class="listIndex">2.</span>
# <span class="rest-row-name-text">barmini by José Andrés</span>
# <span class="star-rating-text">(292)</span>
# <span class="star-rating-text--review-text">292 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">93% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Bar / Lounge / Bottle Service</span>
# <span class="rest-row-meta--location rest-row-meta-text">Penn Quarter</span>
# <span class="listIndex">3.</span>
# <span class="rest-row-name-text">Fish by Jose Andres - MGM National Harbor</span>
# <span class="new-restaurant-tag">New</span>
# <span class="star-rating-text">(9)</span>
# <span class="star-rating-text--review-text">9 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">85% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">85% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Seafood</span>
# <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>
# <span class="listIndex">4.</span>
# <span class="rest-row-name-text">Le Diplomate</span>
# <span class="star-rating-text">(4250)</span>
# <span class="star-rating-text--review-text">4250 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">95% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">95% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">French</span>
# <span class="rest-row-meta--location rest-row-meta-text">Logan Circle</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 2 timeslots left!</span>
# <span class="listIndex">5.</span>
# <span class="rest-row-name-text">Rasika</span>
# <span class="star-rating-text">(6356)</span>
# <span class="star-rating-text--review-text">6356 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">95% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">95% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Indian</span>
# <span class="rest-row-meta--location rest-row-meta-text">Penn Quarter</span>
# <span class="listIndex">6.</span>
# <span class="rest-row-name-text">Kinship</span>
# <span class="star-rating-text">(255)</span>
# <span class="star-rating-text--review-text">255 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">89% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">89% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Mt. Vernon Square</span>
# <span class="listIndex">7.</span>
# <span class="rest-row-name-text">Rasika West End</span>
# <span class="star-rating-text">(2675)</span>
# <span class="star-rating-text--review-text">2675 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">90% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">90% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary Indian</span>
# <span class="rest-row-meta--location rest-row-meta-text">West End</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 2 timeslots left!</span>
# <span class="listIndex">8.</span>
# <span class="rest-row-name-text">Sushi Taro</span>
# <span class="star-rating-text">(1307)</span>
# <span class="star-rating-text--review-text">1307 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">92% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">92% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Japanese</span>
# <span class="rest-row-meta--location rest-row-meta-text">Dupont Circle</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 2 timeslots left!</span>
# <span class="listIndex">9.</span>
# <span class="rest-row-name-text">The Goodstone Inn &amp; Estate Restaurant</span>
# <span class="star-rating-text">(700)</span>
# <span class="star-rating-text--review-text">700 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">81% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">81% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">French</span>
# <span class="rest-row-meta--location rest-row-meta-text">Middleburg</span>
# <span class="listIndex">10.</span>
# <span class="rest-row-name-text">Elizabeth's Gone Raw</span>
# <span class="star-rating-text">(131)</span>
# <span class="star-rating-text--review-text">131 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">100% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">100% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Vegan</span>
# <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>
# <span class="listIndex">11.</span>
# <span class="rest-row-name-text">Iron Gate Patio &amp; Garden</span>
# <span class="star-rating-text">(201)</span>
# <span class="star-rating-text--review-text">201 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">87% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">87% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mediterranean</span>
# <span class="rest-row-meta--location rest-row-meta-text">Dupont Circle</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">12.</span>
# <span class="rest-row-name-text">Marcus - MGM National Harbor</span>
# <span class="new-restaurant-tag">New</span>
# <span class="star-rating-text">(39)</span>
# <span class="star-rating-text--review-text">39 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">41% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">41% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>
# <span class="listIndex">13.</span>
# <span class="rest-row-name-text">Roof Terrace Restaurant &amp; Bar</span>
# <span class="star-rating-text">(5111)</span>
# <span class="star-rating-text--review-text">5111 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">77% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">77% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Foggy Bottom</span>
# <span class="listIndex">14.</span>
# <span class="rest-row-name-text">RPM Italian - DC</span>
# <span class="star-rating-text">(425)</span>
# <span class="star-rating-text--review-text">425 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">90% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">90% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Italian</span>
# <span class="rest-row-meta--location rest-row-meta-text">Mt. Vernon Square</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">15.</span>
# <span class="rest-row-name-text">Blue Duck Tavern</span>
# <span class="star-rating-text">(4560)</span>
# <span class="star-rating-text--review-text">4560 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">92% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">92% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">West End</span>
# <span class="listIndex">16.</span>
# <span class="rest-row-name-text">Doi Moi</span>
# <span class="star-rating-text">(309)</span>
# <span class="star-rating-text--review-text">309 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">83% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">83% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Southeast Asian</span>
# <span class="rest-row-meta--location rest-row-meta-text">Logan Circle</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">17.</span>
# <span class="rest-row-name-text">Field &amp; Main</span>
# <span class="star-rating-text">(106)</span>
# <span class="star-rating-text--review-text">106 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">88% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">88% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">The Plains</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">18.</span>
# <span class="rest-row-name-text">Hazel</span>
# <span class="star-rating-text">(152)</span>
# <span class="star-rating-text--review-text">152 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">91% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">91% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Shaw</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 2 timeslots left!</span>
# <span class="listIndex">19.</span>
# <span class="rest-row-name-text">Vasili's Kitchen</span>
# <span class="new-restaurant-tag">New</span>
# <span class="star-rating-text">(26)</span>
# <span class="star-rating-text--review-text">26 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">80% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">80% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mediterranean</span>
# <span class="rest-row-meta--location rest-row-meta-text">Gaithersburg</span>
# <span class="listIndex">20.</span>
# <span class="rest-row-name-text">Uncle Julio's - Gainesville</span>
# <span class="star-rating-text">(144)</span>
# <span class="star-rating-text--review-text">144 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">86% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">86% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mexican</span>
# <span class="rest-row-meta--location rest-row-meta-text">Gainesville</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">21.</span>
# <span class="rest-row-name-text">Founding Farmers - DC</span>
# <span class="star-rating-text">(17901)</span>
# <span class="star-rating-text--review-text">17901 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">89% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">89% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Foggy Bottom</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">22.</span>
# <span class="rest-row-name-text">Ambar</span>
# <span class="star-rating-text">(1078)</span>
# <span class="star-rating-text--review-text">1078 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">97% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">97% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Balkan style</span>
# <span class="rest-row-meta--location rest-row-meta-text">Capitol Hill</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 3 timeslots left!</span>
# <span class="listIndex">23.</span>
# <span class="rest-row-name-text">Joe's Seafood, Prime Steak &amp; Stone Crab - Washington DC</span>
# <span class="star-rating-text">(1990)</span>
# <span class="star-rating-text--review-text">1990 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">95% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">95% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Seafood</span>
# <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 3 timeslots left!</span>
# <span class="listIndex">24.</span>
# <span class="rest-row-name-text">Nostos Restaurant</span>
# <span class="star-rating-text">(2010)</span>
# <span class="star-rating-text--review-text">2010 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">92% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">92% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Greek</span>
# <span class="rest-row-meta--location rest-row-meta-text">Vienna</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 2 timeslots left!</span>
# <span class="listIndex">25.</span>
# <span class="rest-row-name-text">Old Ebbitt Grill</span>
# <span class="star-rating-text">(14294)</span>
# <span class="star-rating-text--review-text">14294 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">94% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">94% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 1 timeslot left!</span>
# <span class="listIndex">26.</span>
# <span class="rest-row-name-text">Ambar - Arlington</span>
# <span class="star-rating-text">(122)</span>
# <span class="star-rating-text--review-text">122 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">93% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Tapas / Small Plates</span>
# <span class="rest-row-meta--location rest-row-meta-text">Arlington</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">27.</span>
# <span class="rest-row-name-text">Farmers &amp; Distillers</span>
# <span class="star-rating-text">(58)</span>
# <span class="star-rating-text--review-text">58 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">79% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">79% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Mt. Vernon Square</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">28.</span>
# <span class="rest-row-name-text">Uncle Julio's - Loudoun</span>
# <span class="star-rating-text">(168)</span>
# <span class="star-rating-text--review-text">168 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">84% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">84% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mexican</span>
# <span class="rest-row-meta--location rest-row-meta-text">Ashburn</span>
# <span class="listIndex">29.</span>
# <span class="rest-row-name-text">Restaurant Eve</span>
# <span class="star-rating-text">(917)</span>
# <span class="star-rating-text--review-text">917 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">81% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">81% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Old Town Alexandria</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">30.</span>
# <span class="rest-row-name-text">Ruth's Chris Steak House - Gaithersburg</span>
# <span class="star-rating-text">(278)</span>
# <span class="star-rating-text--review-text">278 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">91% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">91% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Steakhouse</span>
# <span class="rest-row-meta--location rest-row-meta-text">Gaithersburg</span>
# <span class="listIndex">31.</span>
# <span class="rest-row-name-text">Landini Brothers</span>
# <span class="star-rating-text">(1483)</span>
# <span class="star-rating-text--review-text">1483 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">93% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Italian</span>
# <span class="rest-row-meta--location rest-row-meta-text">Alexandria</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">32.</span>
# <span class="rest-row-name-text">Bombay Club</span>
# <span class="star-rating-text">(2931)</span>
# <span class="star-rating-text--review-text">2931 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">94% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">94% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Indian</span>
# <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">33.</span>
# <span class="rest-row-name-text">TAP Sports Bar - MGM National Harbor</span>
# <span class="new-restaurant-tag">New</span>
# <span class="star-rating-text">(6)</span>
# <span class="star-rating-text--review-text">6 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">100% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">100% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Comfort Food</span>
# <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>
# <span class="listIndex">34.</span>
# <span class="rest-row-name-text">The Melting Pot - Reston</span>
# <span class="star-rating-text">(2252)</span>
# <span class="star-rating-text--review-text">2252 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">90% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">90% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Fondue</span>
# <span class="rest-row-meta--location rest-row-meta-text">Reston</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">35.</span>
# <span class="rest-row-name-text">Ted's Bulletin - 14th Street</span>
# <span class="star-rating-text">(143)</span>
# <span class="star-rating-text--review-text">143 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">100% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">100% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Comfort Food</span>
# <span class="rest-row-meta--location rest-row-meta-text">Logan Circle</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 1 timeslot left!</span>
# <span class="listIndex">36.</span>
# <span class="rest-row-name-text">Texas de Brazil - Fairfax</span>
# <span class="star-rating-text">(813)</span>
# <span class="star-rating-text--review-text">813 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">91% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">91% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Brazilian Steakhouse</span>
# <span class="rest-row-meta--location rest-row-meta-text">Fairfax</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">37.</span>
# <span class="rest-row-name-text">Farmers Fishers Bakers</span>
# <span class="star-rating-text">(4227)</span>
# <span class="star-rating-text--review-text">4227 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">88% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">88% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Georgetown</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">38.</span>
# <span class="rest-row-name-text">Plume at the Jefferson Hotel</span>
# <span class="star-rating-text">(921)</span>
# <span class="star-rating-text--review-text">921 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">86% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">86% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>
# <span class="listIndex">39.</span>
# <span class="rest-row-name-text">Uncle Julio's - Bethesda Row</span>
# <span class="star-rating-text">(115)</span>
# <span class="star-rating-text--review-text">115 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">91% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">91% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mexican</span>
# <span class="rest-row-meta--location rest-row-meta-text">Bethesda / Chevy Chase</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">40.</span>
# <span class="rest-row-name-text">Plan B Burger Bar - Washington DC</span>
# <span class="star-rating-text">(26)</span>
# <span class="star-rating-text--review-text">26 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">72% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">72% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Burgers</span>
# <span class="rest-row-meta--location rest-row-meta-text">Washington</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">41.</span>
# <span class="rest-row-name-text">Ginger - MGM National Harbor</span>
# <span class="new-restaurant-tag">New</span>
# <span class="star-rating-text">(25)</span>
# <span class="star-rating-text--review-text">25 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">60% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">60% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Asian</span>
# <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span>
# <span class="listIndex">42.</span>
# <span class="rest-row-name-text">Uncle Julio's - Gaithersburg</span>
# <span class="star-rating-text">(121)</span>
# <span class="star-rating-text--review-text">121 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">96% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">96% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mexican</span>
# <span class="rest-row-meta--location rest-row-meta-text">Gaithersburg</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">43.</span>
# <span class="rest-row-name-text">Zaytinya</span>
# <span class="star-rating-text">(9840)</span>
# <span class="star-rating-text--review-text">9840 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">93% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mediterranean</span>
# <span class="rest-row-meta--location rest-row-meta-text">Penn Quarter</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">44.</span>
# <span class="rest-row-name-text">The Melting Pot - Arlington VA</span>
# <span class="star-rating-text">(1945)</span>
# <span class="star-rating-text--review-text">1945 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">94% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">94% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Fondue</span>
# <span class="rest-row-meta--location rest-row-meta-text">Arlington</span>
# <span class="listIndex">45.</span>
# <span class="rest-row-name-text">Eddie V's - Tysons Corner</span>
# <span class="star-rating-text">(700)</span>
# <span class="star-rating-text--review-text">700 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">96% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">96% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Seafood</span>
# <span class="rest-row-meta--location rest-row-meta-text">Tysons Corner / McLean</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">46.</span>
# <span class="rest-row-name-text">The Melting Pot - Gaithersburg</span>
# <span class="star-rating-text">(1432)</span>
# <span class="star-rating-text--review-text">1432 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">91% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">91% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Fondue</span>
# <span class="rest-row-meta--location rest-row-meta-text">Gaithersburg</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">47.</span>
# <span class="rest-row-name-text">Boqueria - DC</span>
# <span class="star-rating-text">(1142)</span>
# <span class="star-rating-text--review-text">1142 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">95% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">95% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Spanish</span>
# <span class="rest-row-meta--location rest-row-meta-text">Dupont Circle</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">48.</span>
# <span class="rest-row-name-text">1789 Restaurant</span>
# <span class="star-rating-text">(4094)</span>
# <span class="star-rating-text--review-text">4094 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">88% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">88% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Georgetown</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">49.</span>
# <span class="rest-row-name-text">Filomena Ristorante</span>
# <span class="star-rating-text">(7026)</span>
# <span class="star-rating-text--review-text">7026 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">92% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">92% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Italian</span>
# <span class="rest-row-meta--location rest-row-meta-text">Georgetown</span>
# <span class="listIndex">50.</span>
# <span class="rest-row-name-text">Uncle Julio's - Reston Town Center</span>
# <span class="star-rating-text">(92)</span>
# <span class="star-rating-text--review-text">92 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">88% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">88% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mexican</span>
# <span class="rest-row-meta--location rest-row-meta-text">Reston</span>
# <span class="listIndex">51.</span>
# <span class="rest-row-name-text">Estadio</span>
# <span class="star-rating-text">(814)</span>
# <span class="star-rating-text--review-text">814 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">93% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Spanish</span>
# <span class="rest-row-meta--location rest-row-meta-text">Logan Circle</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 2 timeslots left!</span>
# <span class="listIndex">52.</span>
# <span class="rest-row-name-text">Harrimans Virginia Piedmont Grill</span>
# <span class="star-rating-text">(266)</span>
# <span class="star-rating-text--review-text">266 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">76% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">76% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary American</span>
# ...
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Downtown</span>
# <span class="listIndex">78.</span>
# <span class="rest-row-name-text">Seasons Restaurant - Four Seasons Washington DC</span>
# <span class="star-rating-text">(377)</span>
# <span class="star-rating-text--review-text">377 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">96% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">96% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Georgetown</span>
# <span class="listIndex">79.</span>
# <span class="rest-row-name-text">VOLT</span>
# <span class="star-rating-text">(4217)</span>
# <span class="star-rating-text--review-text">4217 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">91% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">91% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Frederick</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">80.</span>
# <span class="rest-row-name-text">Trummer's on Main</span>
# <span class="star-rating-text">(2708)</span>
# <span class="star-rating-text--review-text">2708 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">93% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Clifton</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">81.</span>
# <span class="rest-row-name-text">Marriott Westfields - Fairfax Dining Room</span>
# <span class="star-rating-text">(195)</span>
# <span class="star-rating-text--review-text">195 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">100% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">100% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Chantilly</span>
# <span class="listIndex">82.</span>
# <span class="rest-row-name-text">True Food Kitchen - Fairfax</span>
# <span class="star-rating-text">(229)</span>
# <span class="star-rating-text--review-text">229 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">95% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">95% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mediterranean</span>
# <span class="rest-row-meta--location rest-row-meta-text">Fairfax</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">83.</span>
# <span class="rest-row-name-text">Chaplin</span>
# <span class="star-rating-text">(246)</span>
# <span class="star-rating-text--review-text">246 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">92% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">92% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Japanese</span>
# <span class="rest-row-meta--location rest-row-meta-text">Shaw</span>
# <span class="listIndex">84.</span>
# <span class="rest-row-name-text">L'Auberge Chez Francois</span>
# <span class="star-rating-text">(3595)</span>
# <span class="star-rating-text--review-text">3595 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">99% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">99% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">French</span>
# <span class="rest-row-meta--location rest-row-meta-text">Great Falls</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 2 timeslots left!</span>
# <span class="listIndex">85.</span>
# <span class="rest-row-name-text">The Capital Grille - Washington DC</span>
# <span class="star-rating-text">(2328)</span>
# <span class="star-rating-text--review-text">2328 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">97% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">97% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Steakhouse</span>
# <span class="rest-row-meta--location rest-row-meta-text">Capitol Hill</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">86.</span>
# <span class="rest-row-name-text">The Arsenal at Bluejacket</span>
# <span class="star-rating-text">(545)</span>
# <span class="star-rating-text--review-text">545 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">85% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">85% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Navy Yard</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">87.</span>
# <span class="rest-row-name-text">El Centro D.F. - Georgetown</span>
# <span class="star-rating-text">(506)</span>
# <span class="star-rating-text--review-text">506 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">81% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">81% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary Mexican</span>
# <span class="rest-row-meta--location rest-row-meta-text">Georgetown</span>
# <span class="listIndex">88.</span>
# <span class="rest-row-name-text">Oyamel</span>
# <span class="star-rating-text">(5782)</span>
# <span class="star-rating-text--review-text">5782 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">87% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">87% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mexican</span>
# <span class="rest-row-meta--location rest-row-meta-text">Penn Quarter</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">89.</span>
# <span class="rest-row-name-text">SoBe Restaurant &amp; Lounge</span>
# <span class="star-rating-text">(220)</span>
# <span class="star-rating-text--review-text">220 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">86% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">86% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Lanham</span>
# <span class="clock-icon"></span>
# <span>Hurry, we only have 4 timeslots left!</span>
# <span class="listIndex">90.</span>
# <span class="rest-row-name-text">Clyde's of Chevy Chase</span>
# <span class="star-rating-text">(2188)</span>
# <span class="star-rating-text--review-text">2188 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">95% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">95% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Friendship Heights</span>
# <span class="listIndex">91.</span>
# <span class="rest-row-name-text">BlackSalt</span>
# <span class="star-rating-text">(4276)</span>
# <span class="star-rating-text--review-text">4276 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">94% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">94% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Seafood</span>
# <span class="rest-row-meta--location rest-row-meta-text">Palisades Northwest</span>
# <span class="listIndex">92.</span>
# <span class="rest-row-name-text">Copper Canyon Grill - Glenarden</span>
# <span class="star-rating-text">(882)</span>
# <span class="star-rating-text--review-text">882 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">93% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Lanham</span>
# <span class="listIndex">93.</span>
# <span class="rest-row-name-text">Wildfire - Tysons Galleria</span>
# <span class="star-rating-text">(5278)</span>
# <span class="star-rating-text--review-text">5278 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">93% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Tysons Corner / McLean</span>
# <span class="listIndex">94.</span>
# <span class="rest-row-name-text">Maggiano's - Tyson's Corner</span>
# <span class="star-rating-text">(4049)</span>
# <span class="star-rating-text--review-text">4049 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">93% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Italian</span>
# <span class="rest-row-meta--location rest-row-meta-text">Tysons Corner / McLean</span>
# <span class="listIndex">95.</span>
# <span class="rest-row-name-text">Monocacy Crossing</span>
# <span class="star-rating-text">(1013)</span>
# <span class="star-rating-text--review-text">1013 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">95% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">95% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Contemporary American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Frederick</span>
# <span class="listIndex">96.</span>
# <span class="rest-row-name-text">Uncle Julio's - Fairfax Corner</span>
# <span class="star-rating-text">(104)</span>
# <span class="star-rating-text--review-text">104 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">82% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">82% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Mexican</span>
# <span class="rest-row-meta--location rest-row-meta-text">Fairfax</span>
# <span class="listIndex">97.</span>
# <span class="rest-row-name-text">The Restaurant at Patowmack Farm</span>
# <span class="star-rating-text">(609)</span>
# <span class="star-rating-text--review-text">609 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">98% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">98% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Lovettsville</span>
# <span class="listIndex">98.</span>
# <span class="rest-row-name-text">Earls Kitchen + Bar - Tysons Corner</span>
# <span class="star-rating-text">(193)</span>
# <span class="star-rating-text--review-text">193 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">82% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">82% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Global, International</span>
# <span class="rest-row-meta--location rest-row-meta-text">Tysons Corner / McLean</span>
# <span class="listIndex">99.</span>
# <span class="rest-row-name-text">Founding Farmers - Montgomery County</span>
# <span class="star-rating-text">(6252)</span>
# <span class="star-rating-text--review-text">6252 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">87% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">87% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">American</span>
# <span class="rest-row-meta--location rest-row-meta-text">Rockville</span>
# <span class="listIndex">100.</span>
# <span class="rest-row-name-text">Acqua Al 2</span>
# <span class="star-rating-text">(2135)</span>
# <span class="star-rating-text--review-text">2135 reviews</span>
# <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">94% Recommend</span></span>
# <span class="bullet">•</span>
# <span class="thumbs-up"></span>
# <span class="recommended">94% Recommend</span>
# <span class="rest-row-meta--cuisine rest-row-meta-text">Italian</span>
# <span class="rest-row-meta--location rest-row-meta-text">Capitol Hill</span>
# <span class="pagination-link pagination-prev pagination-unavailable">Previous</span>
# <span class="js-pagination-page pagination-link pagination-current" data-from="0">1</span>
# <span class="js-pagination-page pagination-link " data-from="100">2</span>
# <span class="js-pagination-page pagination-link " data-from="200">3</span>
# <span class="js-pagination-page pagination-spacer " data-from="-1">…</span>
# <span class="js-pagination-page pagination-link " data-from="1800">19</span>
# <span class="js-pagination-page pagination-link " data-from="1900">20</span>
# <span class="js-pagination-page pagination-link " data-from="2000">21</span>
# <span class="footer-copyright">Copyright © 2016 OpenTable, Inc. 1 Montgomery St Ste 700, San Francisco CA 94104 - All rights reserved.</span>
# <span>OpenTable is part of The Priceline Group, the world leader in online travel and related services.</span>

# %% [markdown]
# I still don't see it. Let's search our entire soup object:

# %%
# print out soup, do command+f for "booked "
soup
# Out:
#  <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/> <title>Washington, D.C. Area Restaurants List | OpenTable</title> <meta content="Find Washington, D.C. Area restaurants. Search by location, cuisine, or price to refine restaurant results in the Washington, D.C. Area area." name="description"> </meta> <meta content="noindex" name="robots"> </meta> <link href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-16.png" rel="icon" sizes="16x16"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-32.png" rel="icon" sizes="32x32"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-48.png" rel="icon" sizes="48x48"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-64.png" rel="icon" sizes="64x64"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/favicon-128.png" rel="icon" sizes="128x128"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed"/><meta content="//components.otstatic.com/components/favicon/1.0.4/favicon/apple-touch-icon-152x152-precomposed.png" property="og:image"/><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["favicon"]="1.0.4";</script><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/> <link href="//media.otstatic.com/search-result-node/css/bundle_redesign_search.8da4ca30.css" rel="stylesheet"/><!--[if lte IE 8]><link rel="stylesheet" href="//media.otstatic.com/search-result-node/css/bundle_redesign_search_ie8.9d2e13e7.css" /> <![endif]  --> <script>window.OT = window.OT || {};
# window.OT.SRS = {
#   abTestingAnalytics: {"account":"2d65a94551a4a1caddd5a825a88698a89e19f2d5","hostname":"ac.opentable.com"},
#   ocUrl: window.location.protocol + '//oc-registry.opentable.com/v2/',
#   lang: "en"
# };
# </script><!--[if lte IE 8]> <script src="//components.otstatic.com/components/js-head/1.0.58/min/ie8_compat.js"></script> <![endif]-->
# <!--[if IE 9]> <script src="//components.otstatic.com/components/js-head/1.0.58/min/ie9_compat.js"></script> <![endif]--><script crossorigin="anonymous" src="//components.otstatic.com/components/js-head/1.0.58/min/bundle_head.js"></script><!--[if lte IE 9]> <script src="//components.otstatic.com/components/js-head/1.0.58/min/ie_jquery.js"></script> <![endif]--><script>window.optimizely = window.optimizely || [];
# optimizely.push(['setDimensionValue', 'Language', 'en']);</script><script src="//cdn.optimizely.com/js/174495938.js"></script><script src="//7202552.collect.igodigital.com/collect.js" type="text/javascript"></script><script>try{ Typekit.load(); window.TypekitLoaded = true; } catch(e){ window.TypekitLoaded = false; }</script><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["js-head"]="1.0.58";</script><!--[if IE]><script src="//media.otstatic.com/search-result-node/js/generated/ie_compat.d69a1eb0.js"></script>
# <![endif]-->
# <script type="text/javascript">
#                       var w=window;
#                       if(w.performance||w.mozPerformance||w.msPerformance||w.webkitPerformance){var d=document,AKSB=AKSB||{};AKSB.q=[];AKSB.mark=function(a,b){AKSB.q.push(["mark",a,b||(new Date).getTime()])};AKSB.measure=function(a,b,c){AKSB.q.push(["measure",a,b,c||(new Date).getTime()])};AKSB.done=function(a){AKSB.q.push(["done",a])};AKSB.mark("firstbyte",(new Date).getTime());AKSB.prof={custid:"189702",ustr:"UNKNOWN",originlat:0,clientrtt:54,ghostip:"23.205.120.158",
#                       ipv6:false,pct:10,clientip:"50.200.196.50",requestid:"2c3f80cd",protocol:"",blver:10,akM:"x",akN:"ae",akTT:"O",akTX:"1",akTI:"2c3f80cd",ai:"268571",ra:"",pmgn:"",pmgi:"",pmp:""};(function(a){var b=
#                       d.createElement("script");b.async="async";b.src=a;a=d.getElementsByTagName("script");a=a[a.length-1];a.parentNode.insertBefore(b,a)})(("https:"===d.location.protocol?"https:":"http:")+"//ds-aksb-a.akamaihd.net/aksb.min.js")};
#                     </script>
# </head><body class="search com domain-com list has-results availability-search initial-load not-multi-search page-type-2 appendRegionDescription domainCulture genericExperiment otRequestId recordRestaurantCount showRestaurantListLink togglePop"> <!-- Anti-Forgery Token Here --><div class="master-container" id="search-master-container"> <style>.icon-font{font-family:'icons';speak:none;font-style:normal;font-weight:normal;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.breadcrumb li.icon-visible a:before{font-family:'icons';speak:none;font-style:normal;font-weight:normal;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.breadcrumb{*zoom:1;background-color:#ffffff;height:2rem;line-height:1.9rem;font-size:0.75rem;border-top:1px solid rgba(0, 0, 0, 0.08);border-bottom:none !important;padding:0 1.25rem}.breadcrumb:before,.breadcrumb:after{content:" ";display:table}.breadcrumb:after{clear:both}@media only screen and (min-width: 64.0625em){.breadcrumb{padding:0 2.25rem}}.breadcrumb li{position:relative;display:block;float:left;margin:0 1rem 0 0.35rem}.breadcrumb li.hidden{display:none}@media only screen and (min-width: 40.0625em){.breadcrumb li.hidden{display:block}}.breadcrumb li.icon-visible{margin-left:0;height:100%;width:1.25rem}@media only screen and (min-width: 40.0625em){.breadcrumb li.icon-visible{margin-left:0.35rem;width:auto}}.breadcrumb li.icon-visible a{display:block;width:100%;height:100%}.breadcrumb li.icon-visible a span{display:none}@media only screen and (min-width: 40.0625em){.breadcrumb li.icon-visible a span{display:block}}.breadcrumb li.icon-visible a:before{content:"a";display:block;width:1.5rem;height:2rem;line-height:2rem;text-align:center;position:absolute;font-size:1rem}@media only screen and (min-width: 40.0625em){.breadcrumb li.icon-visible a:before{display:none}}.breadcrumb li:first-child{margin-left:0}.breadcrumb li:last-child{margin-right:0}.breadcrumb li:last-child:after,.breadcrumb li:last-child:before{display:none}.breadcrumb li:after,.breadcrumb li:before{content:'';position:absolute;left:100%;margin-left:0.25rem}.breadcrumb li:before{top:-1px;border-top:1rem solid transparent;border-bottom:1rem solid transparent;border-left:0.6rem solid rgba(0, 0, 0, 0.2)}.breadcrumb li:after{top:0;border-top:0.96rem solid transparent;border-bottom:0.96rem solid transparent;border-left:0.56rem solid #ffffff}.domain-comau .top-bar-nav-link.icon-location{line-height:55px}.domain-comau .top-bar-nav-link.icon-location:before{color:rgba(0, 0, 0, 0.12);font-size:18px;position:relative;top:4px;left:-2px}.domain-comau .with-location-picker .tab-bar-logo{margin-left:48px}.domain-comau .hamburger-menu .top-bar-nav-link{line-height:50px}.menu-drawer-left.sliding-menu .menu-close:after{font-family:'icons';speak:none;font-style:normal;font-weight:normal;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.menu-drawer-left.sliding-menu{position:fixed;background-color:unset;top:0;left:0;width:100%;height:100%;pointer-events:none;transition:background-color 0.25s ease-out}.menu-drawer-left.sliding-menu.menu-opened{background-color:rgba(0, 0, 0, 0.5);pointer-events:auto}.menu-drawer-left.sliding-menu.menu-opened:before{content:none}.menu-drawer-left.sliding-menu.menu-opened .menu-container{transform:translate3d(0, 0, 0)}.menu-drawer-left.sliding-menu .menu-container{width:220px;height:100%;max-height:initial;transition:transform 0.5s ease-out;transform:translate3d(-220px, 0, 0);opacity:1}.menu-drawer-left.sliding-menu .menu-container .menu-main{border-radius:0;box-shadow:none;width:100%;height:100%;margin:0;padding:3rem 0 0.25rem 0}.menu-drawer-left.sliding-menu .menu-list-link{transition:color 0.15s ease-out;font-size:0.875rem;padding:0.5rem 1rem 0.5rem 1.5rem}.menu-drawer-left.sliding-menu .menu-list-link-primary ...
# window.pageData.serialisedMetros = [{"n":"Atlanta / Georgia","d":"Atlanta / Georgia","m":16,"cn":"United States","did":1,"l":"en","u":"1/atlanta-restaurants","r":1622,"ma":[{"n":"Atlanta","m":50,"u":"1/atlanta-restaurants?mn=50","r":723},{"n":"Alpharetta / Roswell","m":199,"u":"1/atlanta-restaurants?mn=199","r":151},{"n":"Northeast Atlanta","m":1012,"u":"1/atlanta-restaurants?mn=1012","r":230},{"n":"South Atlanta","m":1015,"u":"1/atlanta-restaurants?mn=1015","r":80},{"n":"Northwest Atlanta","m":201,"u":"1/atlanta-restaurants?mn=201","r":211},{"n":"Statesboro","m":2950,"u":"1/atlanta-restaurants?mn=2950","r":6},{"n":"Columbus","m":1759,"u":"1/atlanta-restaurants?mn=1759","r":35},{"n":"Athens","m":2152,"u":"1/atlanta-restaurants?mn=2152","r":17},{"n":"Augusta","m":1084,"u":"1/atlanta-restaurants?mn=1084","r":57},{"n":"N. GA Mountains / Wine Country","m":1390,"u":"1/atlanta-restaurants?mn=1390","r":30},{"n":"Macon","m":1165,"u":"1/atlanta-restaurants?mn=1165","r":52},{"n":"Swainsboro","m":2092,"u":"1/atlanta-restaurants?mn=2092","r":2},{"n":"Braselton","m":2701,"u":"1/atlanta-restaurants?mn=2701","r":9},{"n":"Pine Mountain","m":2809,"u":"1/atlanta-restaurants?mn=2809","r":3},{"n":"Thomasville","m":2521,"u":"1/atlanta-restaurants?mn=2521","r":16}],"f":true},{"n":"Baltimore / Maryland","d":"Baltimore Area","m":18,"cn":"United States","did":1,"l":"en","u":"1/baltimore-restaurants","r":844,"ma":[{"n":"Chambersburg","m":2956,"u":"1/baltimore-restaurants?mn=2956","r":1},{"n":"Baltimore","m":59,"u":"1/baltimore-restaurants?mn=59","r":268},{"n":"Baltimore Suburbs","m":187,"u":"1/baltimore-restaurants?mn=187","r":291},{"n":"Ocean City / Delaware Shore","m":1153,"u":"1/baltimore-restaurants?mn=1153","r":97},{"n":"Greater Annapolis","m":88,"u":"1/baltimore-restaurants?mn=88","r":85},{"n":"Eastern Shore","m":189,"u":"1/baltimore-restaurants?mn=189","r":76},{"n":"Western MD","m":186,"u":"1/baltimore-restaurants?mn=186","r":26}],"f":true},{"n":"Boston / New England","d":"Boston / New England","m":7,"cn":"United States","did":1,"l":"en","u":"1/boston-restaurants","r":3588,"ma":[{"n":"Boston","m":47,"u":"1/boston-restaurants?mn=47","r":808},{"n":"Boston Suburbs","m":206,"u":"1/boston-restaurants?mn=206","r":991},{"n":"Central MA","m":207,"u":"1/boston-restaurants?mn=207","r":194},{"n":"Western MA","m":208,"u":"1/boston-restaurants?mn=208","r":159},{"n":"Southern MA","m":406,"u":"1/boston-restaurants?mn=406","r":82},{"n":"Cape Cod and the Islands","m":90,"u":"1/boston-restaurants?mn=90","r":195},{"n":"Maine","m":105,"u":"1/boston-restaurants?mn=105","r":345},{"n":"Rhode Island","m":92,"u":"1/boston-restaurants?mn=92","r":294},{"n":"Vermont","m":114,"u":"1/boston-restaurants?mn=114","r":219},{"n":"New Hampshire","m":131,"u":"1/boston-restaurants?mn=131","r":301}],"f":true},{"n":"Chicago / Illinois","d":"Chicago / Illinois","m":3,"cn":"United States","did":1,"l":"en","u":"1/chicago-restaurants","r":2880,"ma":[{"n":"Chicago","m":11,"u":"1/chicago-restaurants?mn=11","r":1214},{"n":"North Suburbs","m":12,"u":"1/chicago-restaurants?mn=12","r":305},{"n":"West Suburbs","m":15,"u":"1/chicago-restaurants?mn=15","r":390},{"n":"Northwest Suburbs","m":107,"u":"1/chicago-restaurants?mn=107","r":290},{"n":"Southwest Suburbs","m":198,"u":"1/chicago-restaurants?mn=198","r":138},{"n":"Near West","m":1429,"u":"1/chicago-restaurants?mn=1429","r":85},{"n":"South Suburbs","m":13,"u":"1/chicago-restaurants?mn=13","r":81},{"n":"Central Illinois","m":108,"u":"1/chicago-restaurants?mn=108","r":197},{"n":"Galena","m":197,"u":"1/chicago-restaurants?mn=197","r":9},{"n":"Northwest Indiana","m":1369,"u":"1/chicago-restaurants?mn=1369","r":77},{"n":"Rockford","m":1582,"u":"1/chicago-restaurants?mn=1582","r":48},{"n":"Southern Illinois","m":1711,"u":"1/chicago-restaurants?mn=1711","r":27},{"n":"Rochelle","m":2224,"u":"1/chicago-restaurants?mn=2224","r":11},{"n":"Thomson","m":2584,"u":"1/chicago-restaurants?mn=2584","r":8}],"f":true},{"n":"Dallas - Fort Worth","d":"Dallas","m":20 ...
# window.pageData.metroId = 9;
# window.pageData.words = { all: 'All {0}', table: '', usernameWelcome: 'Hello!' };
# window.pageData.headerSignedIn = false;</script><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["header"]="1.4.0";</script><div class="search-image"> <div class="image-container "><div class="max-width-wrapper"><div class="overlay-text" id="overlay_text"><div class="page-header-content"><div class="row"><div class="column"> <h1 class="needs-emblem-offset"> All Washington, D.C. Area restaurants</h1> </div></div></div></div></div></div> <div class="search-control labels cf" id="search_control"> <div class="page-header cf"><div class="max-width-wrapper"><div class="page-header-content"><div class="row"><div class="column"> <oc-component data-hash="9e33d6554ea991185918d1fe3caa4404d39b23cc" data-name="dtp" data-rendered="true" data-version="1.2.0" href="https://oc-registry.opentable.com/v2/dtp/1.2.0?twoBoxSearch=false&amp;dateTime=2016-12-22T19%3A00&amp;metroId=9&amp;partySize=2&amp;showLargerParty=true&amp;showSearch=true&amp;searchPlaceholder=Location%2C%20Restaurant%2C%20or%20Cuisine&amp;theme=com"><style>.rest-dtp-picker-wrapper{background:#ECECEC;border-radius:5px;-webkit-box-shadow:0 1px 0px rgba(0, 0, 0, 0.1);box-shadow:0 1px 0px rgba(0, 0, 0, 0.1);margin-bottom:2rem}.rest-dtp-picker-wrapper .dtp-picker{border-radius:4px;-webkit-box-shadow:0 1px 0px rgba(0, 0, 0, 0.1);box-shadow:0 1px 0px rgba(0, 0, 0, 0.1)}.rest-dtp-picker-wrapper .dtp-result-text{margin-top:0;margin-bottom:1rem}.dtp-picker{*zoom:1;margin:0;position:relative;border:none !important;border-radius:0 !important;background:none !important}.dtp-picker:before,.dtp-picker:after{content:" ";display:table}.dtp-picker:after{clear:both}.dtp-picker .highlighted{border:1px solid #60B2D0 !important}.dtp-picker.double-search .highlighted .dtp-picker-search-icon{color:#DA3743}.dtp-picker .twitter-typeahead{width:100%}.dtp-picker.single-search .tt-suggestion p{padding:0.5rem 1rem 0.5rem 2.4375rem}.dtp-picker-selector{width:33.3333%;float:left;background:#fff;position:relative;height:3rem;margin:0;border:1px solid rgba(0, 0, 0, 0.08);border-bottom:none}.search-control .dtp-picker-selector{background:#f3f2f1}.dtp-picker-selector.party-size-picker{border-right:0;border-top-left-radius:3px}.double-search .dtp-picker-selector.party-size-picker{border-top-left-radius:0}@media only screen and (min-width: 40.0625em){.dtp-picker-selector.party-size-picker{border-bottom-left-radius:3px}.with-search .dtp-picker-selector.party-size-picker{border-bottom-left-radius:0}.double-search .dtp-picker-selector.party-size-picker{border-bottom-left-radius:0}.dtp-lang-en.with-search .dtp-picker-selector.party-size-picker{width:22%}.dtp-lang-ja.with-search .dtp-picker-selector.party-size-picker{width:11%}.dtp-lang-de.with-search .dtp-picker-selector.party-size-picker{width:19%}.dtp-lang-es.with-search .dtp-picker-selector.party-size-picker{width:21%}.dtp-lang-fr.with-search .dtp-picker-selector.party-size-picker{width:23%}}@media only screen and (min-width: 48.0625em){.with-search .dtp-picker-selector.party-size-picker{border-bottom-left-radius:3px}.double-search .dtp-picker-selector.party-size-picker{border-bottom-left-radius:0}.dtp-lang-en.with-search .dtp-picker-selector.party-size-picker,.dtp-lang-ja.with-search .dtp-picker-selector.party-size-picker,.dtp-lang-de.with-search .dtp-picker-selector.party-size-picker,.dtp-lang-es.with-search .dtp-picker-selector.party-size-picker,.dtp-lang-fr.with-search .dtp-picker-selector.party-size-picker{width:15%}}.dtp-picker-selector.date-picker{border-right:0}@media only screen and (min-width: 40.0625em){.dtp-picker-selector.date-picker{width:23%}.dtp-lang-es.with-search .dtp-picker-selector.date-picker{width:21%}.dtp-lang-fr.with-search .dtp-picker-selector.date-picker{width:22%}}@media only screen and (min-width: 48.0625em){.dtp-picker.with-search .dtp-picker-selector.date-picker{width:23%}.dtp-lang-es.with-search .dtp-picker-selector.date-picker,.dtp-picker-selector.date-picker .dtp-lang-fr.with-search ...
#     .tt-dropdown-menu:before {
#         background-image: url('//components.otstatic.com/components/dtp/1.2.0/img/menu-arrow@2x.png') !important;
#         background-size: 100%;
#     }
# }
# </style><div class="dtp-picker hide dtp-lang-en with-search single-search"><form class="dtp-picker-form"><input name="timezoneOffset" title="timezoneOffset" type="hidden" value="-300"/><select class="party-size-picker hide"><option value="1">1 person</option><option selected="selected" value="2">2 people</option><option value="3">3 people</option><option value="4">4 people</option><option value="5">5 people</option><option value="6">6 people</option><option value="7">7 people</option><option value="8">8 people</option><option value="9">9 people</option><option value="10">10 people</option><option value="11">11 people</option><option value="12">12 people</option><option value="13">13 people</option><option value="14">14 people</option><option value="15">15 people</option><option value="16">16 people</option><option value="17">17 people</option><option value="18">18 people</option><option value="19">19 people</option><option value="20">20 people</option><option value="21">Larger party</option></select><input class="date-picker dtp-picker-selector" title="datePicker" type="text" value="2016-12-22"/><select class="time-picker hide"><option value="00:00">12:00 AM</option><option value="00:30">12:30 AM</option><option value="01:00">1:00 AM</option><option value="01:30">1:30 AM</option><option value="02:00">2:00 AM</option><option value="02:30">2:30 AM</option><option value="03:00">3:00 AM</option><option value="03:30">3:30 AM</option><option value="04:00">4:00 AM</option><option value="04:30">4:30 AM</option><option value="05:00">5:00 AM</option><option value="05:30">5:30 AM</option><option value="06:00">6:00 AM</option><option value="06:30">6:30 AM</option><option value="07:00">7:00 AM</option><option value="07:30">7:30 AM</option><option value="08:00">8:00 AM</option><option value="08:30">8:30 AM</option><option value="09:00">9:00 AM</option><option value="09:30">9:30 AM</option><option value="10:00">10:00 AM</option><option value="10:30">10:30 AM</option><option value="11:00">11:00 AM</option><option value="11:30">11:30 AM</option><option value="12:00">12:00 PM</option><option value="12:30">12:30 PM</option><option value="13:00">1:00 PM</option><option value="13:30">1:30 PM</option><option value="14:00">2:00 PM</option><option value="14:30">2:30 PM</option><option value="15:00">3:00 PM</option><option value="15:30">3:30 PM</option><option value="16:00">4:00 PM</option><option value="16:30">4:30 PM</option><option value="17:00">5:00 PM</option><option value="17:30">5:30 PM</option><option value="18:00">6:00 PM</option><option value="18:30">6:30 PM</option><option selected="selected" value="19:00">7:00 PM</option><option value="19:30">7:30 PM</option><option value="20:00">8:00 PM</option><option value="20:30">8:30 PM</option><option value="21:00">9:00 PM</option><option value="21:30">9:30 PM</option><option value="22:00">10:00 PM</option><option value="22:30">10:30 PM</option><option value="23:00">11:00 PM</option><option value="23:30">11:30 PM</option></select><div class="dtp-picker-search-container"><div class="dtp-picker-search-icon icon-search"></div><input class="dtp-picker-search" id="dtp-search-single-box" name="searchText" placeholder="Location, Restaurant, or Cuisine" title="searchText" type="text" value=""/></div><input class="button dtp-picker-button" type="submit" value="Find a Table"/></form><script>window.OT = window.OT || {};
# window.dtp_data = { theme: 'com', lang: 'en', ocUrl: 'na-srs.opentable.com/v2/', allowYesterday: false};
# </script><script src="//components.otstatic.com/components/dtp/1.2.0/dist/dtp.js"></script></div><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["dtp"]="1.2.0";</script></oc-component></div></div></div></div></div></div></div> <div class="filters-bar show-filter-content" id="filters-bar"><div class="max-width-wrapper"><div class="row"><div class="column"> <div id="search_filters"> <ul class="filters-list"> <li class="filter-option filter-option-locations" id="location_filters"> <span class="filters" data-target="Regions-filter-menu"><span class="location-icon filter-icon"></span> <span class="filter-list-title">Regions</span> <span class="filter-count"></span></span><div class="menu with-arrow search-filter-menu" id="Regions-filter-menu"><div class="menu-container"><div class="menu-main collapsed"><div class="menu-section "><div class="menu-list "><div class="menu-with-checkboxes" id="Regions-filter-items"> <ul class="view-filter-list"> <li> <label class="filter-toggle menu-list-label" for="RegionIds_All"><input class="menu-list-input" id="RegionIds_All" type="checkbox"/> <span title="All Locations">All Locations</span></label></li> <li> <label class="menu-list-label show-filter" for="RegionIds_35"><input class="filter menu-list-input" data-filter-name="RegionIds" data-id="35" id="RegionIds_35" name="RegionIds" type="checkbox"> </input> <span title="District of Columbia"> District of Columbia </span></label> </li> <li> <label class="menu-list-label show-filter" for="RegionIds_188"><input class="filter menu-list-input" data-filter-name="RegionIds" data-id="188" id="RegionIds_188" name="RegionIds" type="checkbox"> </input> <span title="Maryland - DC Suburbs"> Maryland - DC Suburbs </span></label> </li> <li> <label class="menu-list-label show-filter" for="RegionIds_36"><input class="filter menu-list-input" data-filter-name="RegionIds" data-id="36" id="RegionIds_36" name="RegionIds" type="checkbox"> </input> <span title="Virginia - DC Suburbs"> Virginia - DC Suburbs </span></label> </li> </ul></div></div></div> </div></div></div> </li> <li class="filter-option filter-option-cuisines" id="cuisine_filters"> <span class="filters" data-target="Cuisines-filter-menu"><span class="cuisine-icon filter-icon"></span> <span class="filter-list-title">Cuisine</span> <span class="filter-count"></span></span><div class="menu with-arrow search-filter-menu" id="Cuisines-filter-menu"><div class="menu-container"><div class="menu-main collapsed"><div class="menu-section with-scroll"><div class="menu-list with-overflow"><div class="menu-with-checkboxes" id="Cuisines-filter-items"> <ul class="view-filter-list"> <li> <label class="filter-toggle menu-list-label" for="CuisineIds_All"><input class="menu-list-input" id="CuisineIds_All" type="checkbox"/> <span title="All Cuisines">All Cuisines</span></label></li> <li> <label class="menu-list-label show-filter" for="CuisineIds_ef31bf77-2c58-4ffe-bacc-faf80394a3d0"><input class="filter menu-list-input" data-filter-name="CuisineIds" data-id="ef31bf77-2c58-4ffe-bacc-faf80394a3d0" id="CuisineIds_ef31bf77-2c58-4ffe-bacc-faf80394a3d0" name="CuisineIds" type="checkbox"> </input> <span title="Afghan"> Afghan </span></label> </li> <li> <label class="menu-list-label show-filter" for="CuisineIds_41753431-959b-4713-8a73-994980ba8a20"><input class="filter menu-list-input" data-filter-name="CuisineIds" data-id="41753431-959b-4713-8a73-994980ba8a20" id="CuisineIds_41753431-959b-4713-8a73-994980ba8a20" name="CuisineIds" type="checkbox"> </input> <span title="African"> African </span></label> </li> <li> <label class="menu-list-label show-filter" for="CuisineIds_c6c2a49e-0d43-4ea0-b4ff-40a612e5aabc"><input class="filter menu-list-input" data-filter-name="CuisineIds" data-id="c6c2a49e-0d43-4ea0-b4ff-40a612e5aabc" id="CuisineIds_c6c2a49e-0d43-4ea0-b4ff-40a612e5aabc" name="CuisineIds" type="checkbox"> </input> <span title="Afternoon Tea"> Afternoon Tea </span></label> </li> <l ...
#   $('.email-signup').html(oc.build({
#     baseUrl: OT.SRS.ocUrl,
#     name: 'oc_component_email_signup',
#     parameters: { language: OT.SRS.lang, metroId: '9' }
#   }));
#
#   oc.renderUnloadedComponents();
# });</script><div class="footer-content-container"><div class="footer-block"><h6>Discover</h6><ul><li><a href="https://community.opentable.com/t5/Points/ct-p/Points?profile.language=en" target="_blank">Dining Rewards<img class="hide"/></a></li><li><a href="http://www.opentable.com/m/private-dining-restaurants-in-north-america/">Private Dining<img class="hide"/></a></li><li><a href="http://www.opentable.com/m/best-restaurants-in-america-for-2015/">Top 100 Restaurants<img class="hide"/></a></li><li><a href="https://community.opentable.com/t5/FAQs-Knowledge-Base/How-do-I-make-reservations-for-others/ta-p/123?profile.language=en" target="_blank">Reserve for Others<img class="hide"/></a></li></ul></div><div class="footer-block"><h6>OpenTable</h6><ul><li><a href="http://www.opentable.com/about/">About Us<img class="hide"/></a></li><li><a href="http://blog.opentable.com">Blog<img class="hide"/></a></li><li><a href="http://www.opentable.com/careers/">Careers<img class="hide"/></a></li><li><a href="http://press.opentable.com">Press<img class="hide"/></a></li><li><a href="http://www.rgmgroup.com/advertisers-opentable.html">Advertise<img class="hide"/></a></li></ul></div><div class="footer-block"><h6>More</h6><ul><li><a href="http://www.opentable.co.uk">OpenTable.co.uk<img class="hide"/></a></li><li><a href="https://336481.measurementapi.com/serve?action=click&amp;publisher_id=336481&amp;site_id=13216" target="_blank">OpenTable for iOS<img class="hide"/></a></li><li><a href="https://336481.measurementapi.com/serve?action=click&amp;publisher_id=336481&amp;site_id=13212" target="_blank">OpenTable for Android<img class="hide"/></a></li><li><a href="https://community.opentable.com/t5/FAQs-Knowledge-Base/OpenTable-Affiliate-Program/ta-p/400?profile.language=en" target="_blank">Affiliate Program<img class="hide"/></a></li><li><a href="https://community.opentable.com/t5/OpenTable-Community/ct-p/OpenTable_Community_US?profile.language=en" target="_blank">Contact Us<img class="hide"/></a></li><li><a href="https://community.opentable.com/t5/OpenTable-Community/ct-p/OpenTable_Community_US?profile.language=en" target="_blank">Help &amp; Support<img class="hide"/></a></li></ul></div><div class="footer-block"><h6>Restaurateurs</h6><a class="button small with-arrow text-arrow-right" href="https://restaurant.opentable.com/get-started/?ls=DinerSite&amp;mid=Footer&amp;utm_source=otcom&amp;utm_campaign=C4A">Delight more diners<img class="hide"/></a><a class="button small with-arrow text-arrow-right" href="http://openforbusiness.opentable.com" target="_blank">Open for Business Blog<img class="hide"/></a><h6>Join us on</h6><div class="footer-social-links"><a class="footer-social-link twitter" href="http://twitter.com/opentable" target="_blank" title="twitter"><img alt="twitter" class="hide"/></a><a class="footer-social-link facebook" href="http://www.facebook.com/OpenTable" target="_blank" title="facebook"><img alt="facebook" class="hide"/></a><a class="footer-social-link google" href="http://plus.google.com/+OpenTable/" target="_blank" title="google"><img alt="google" class="hide"/></a><a class="footer-social-link linkedin" href="https://www.linkedin.com/company/opentable" target="_blank" title="linkedin"><img alt="linkedin" class="hide"/></a></div></div></div><div class="footer-content-container"><div class="footer-base"><a class="footer-base-link" href="http://www.opentable.com/info/privacypolicy.aspx">Privacy Policy</a><a class="footer-base-link" href="http://www.opentable.com/info/agreement.aspx">Terms of Use</a><a class="footer-base-link" href="http://www.opentable.com/legal/cookie-policy">Cookies and Interest-Based Ads</a><a class="footer-base-link" id="teconsent" style="display: none;"></a><a class="footer-base-link" href="http://www.opentable.com/opentable-sitemap.aspx">Sitemap</a><a class="footer-base-link" href="http://m.opentable.com/">Mobile site</a><br/><span class="footer-copyright">Copyright © 2016 OpenTable, Inc. 1 Montgomery St Ste 700, San  ...
# window.OT.SRS = window.OT.SRS || {};</script><script async="async" crossorigin="localhost" src="//consent.truste.com/notice?domain=opentable.com&amp;c=teconsent&amp;js=bb&amp;noticeType=bb&amp;text=true"></script><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["footer"]="1.0.64";</script><div class="global-footer-system-info"> (Build Version:0.2.182) (Machine Name:prod-sc mesos-slave32-prod-sc.otsql.opentable.com) (Request ID:6e585364-a869-4ca6-8f98-3c786e436277)</div> <div class="page-ad-section hide-for-small-only hide-for-medium-only"> <a class="page-ad-link"><div class="ad-google" data-adtype="FloatingFooter" data-demoland="false" data-metroid="9" data-pagetype="RESTAURANTS_LIST" data-server="18180943" data-user="OpenTable"></div><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["advert"]="2.0.7";</script></a></div> <script>
#   window.OTSearchData = {"DomainInfo":{"id":1,"TopLevelDomain":"com","DomainID":1,"SecureSite":"secure.opentable.com","GoogleMapsAPIKey":"AIzaSyDU_CnonFeRx2tlCV8YAWHA9B3Tam_lja0"},"DomainCulture":{"culture":"en-US","domain":"com","language":"en","isDefaultCulture":true,"defaultMetroId":4,"Culture":"en-US","Domain":"com","Language":"en","addCultureToPath":false},"NoResultsAreaList":[{"Type":"Metro","Name":"Atlanta","Metro":{"Id":16}},{"Type":"Region","Name":"Boston","Metro":{"Id":7},"Region":{"Id":47}},{"Type":"Region","Name":"Chicago","Metro":{"Id":3},"Region":{"Id":11}},{"Type":"Metro","Name":"Dallas","Metro":{"Id":20}},{"Type":"Metro","Name":"Denver","Metro":{"Id":5}},{"Type":"Metro","Name":"Houston","Metro":{"Id":12}},{"Type":"Region","Name":"Las Vegas","Metro":{"Id":10},"Region":{"Id":53}},{"Type":"Metro","Name":"Los Angeles","Metro":{"Id":6}},{"Type":"Metro","Name":"Miami","Metro":{"Id":17}},{"Type":"Metro","Name":"Minneapolis","Metro":{"Id":46}},{"Type":"Region","Name":"New Orleans","Metro":{"Id":14},"Region":{"Id":56}},{"Type":"Region","Name":"New York City","Metro":{"Id":8},"Region":{"Id":16}},{"Type":"Region","Name":"Philadelphia","Metro":{"Id":13},"Region":{"Id":41}},{"Type":"Region","Name":"San Francisco Bay Area","Metro":{"Id":4},"Region":{"Id":5}},{"Type":"Region","Name":"Seattle","Metro":{"Id":2},"Region":{"Id":1}},{"Type":"Metro","Name":"Washington D.C.","Metro":{"Id":9}}],"Experiments":{"bodyClasses":["appendRegionDescription","domainCulture","genericExperiment","otRequestId","recordRestaurantCount","showRestaurantListLink","togglePop"],"enums":{"sv352":{"EXPERIMENT_COOKIE":"OT-SV-352-Show-Tags","EXPERIMENT_NAME":"SV-352"}}},"Request":{"AreaId":null,"AffiliateRestaurantId":null,"Availability":"intersperse","RelatedCount":0,"CurrentView":"list","DateTime":"2016-12-22 19:00","Distance":null,"Domain":"com","DomainCulture":{"domain":"com","culture":"en-US","language":"en","acceptLanguage":"en-US, en, *"},"EnableCultureInUri":false,"ExpandTimeSlots":0,"EnableSimpleCuisines":false,"From":0,"IncludeMetaData":true,"IncludePhotos":null,"IsAcceptanceTest":false,"IsDinersChoiceRequest":false,"IsGeoDistanceRequest":false,"IsAreaIdRequest":false,"JustAdded":null,"Latitude":null,"LegacyHoodId":null,"Limit":100,"Longitude":null,"MetroId":9,"Offset":0,"OnlyExactDateTime":false,"OnlyOffers":false,"OnlyPopTimes":false,"OnlyUnavailable":false,"PageType":2,"PersonalizerAvailability":false,"PersonalizerVersion":null,"PopSchedules":false,"Pre":{"ot-headers":{"Accept-Language":"en-US, en, *","User-Agent":"search-site-node","OT-AnonymousId":"D3E7919E-C2AF-4BF1-9195-870AE84FE8DC","OT-Domain":"com","OT-RequestId":"6e585364-a869-4ca6-8f98-3c786e436277","OT-ReferringHost":"www.opentable.com","OT-ReferringService":"search-api-node"}},"PromoId":null,"Ref":null,"RestRef":null,"SearchQuery":null,"ShowMap":false,"Size":100,"Sort":"Popularity","Tags":null,"Tests":null,"TimeslotSort":"pop","Title":null,"Topic":null,"WishlistId":null,"Covers":2,"IsAvailabilityRequest":true,"ParsedDateTime":"2016-12-22T19:00:00","SortString":"Popularity","MetaData":{"PersonalizerSort":"webConversion"}},"Display":{"SearchBigHeading":"All Washington, D.C. Area restaurants","ShowSearchImage":true,"ShowPop":false,"PageMetaData":{"Title":"Washington, D.C. Area Restaurants List | OpenTable","Description":"Find Washington, D.C. Area restaurants. Search by location, cuisine, or price to refine restaurant results in the Washington, D.C. Area area.","Robots":"noindex","Keywords":null},"ShowTimeSlotsInResults":true,"Availability":"intersperse","CoverOptions":[{"IsSelected":false,"Value":1,"Text":"1 person"},{"IsSelected":true,"Value":2,"Text":"2 people"},{"IsSelected":false,"Value":3,"Text":"3 people"},{"IsSelected":false,"Value":4,"Text":"4 people"},{"IsSelected":false,"Value":5,"Text":"5 people"},{"IsSelected":false,"Value":6,"Text":"6 people"},{"IsSelected":false,"Value":7,"Text":"7 people"},{"IsSelected":false,"Value":8,"Text":"8 people"},{"IsSelected":false,"Value":9,"T ...
# </script> </div><div class="tooltip" id="tooltip"></div><div class="tooltip" id="results_modal"></div><div class="modal filters-modal" id="filters_modal"></div> <script>
#   window.Resources={
#     Strings: {"BookedToday":"Booked {0} times today","Calendar_FirstDay":"0","Calendar_Months":"Jan,Feb,Mar,Apr,May,Jun,Jul,Aug,Sep,Oct,Nov,Dec","Calendar_Weekdays":"Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday","Calendar_WeekdaysShort":"S,M,T,W,T,F,S","Currency":"$","DateFormat":"MM/DD/YYYY","DomainName":"OpenTable","FaviconURL":"/s/static/images/ot/favicon.ico","GlobalFooter":"Copyright &copy; {0} OpenTable, Inc. All rights reserved.","GlobalFooterLink_Privacy":"Privacy Policy","GlobalFooterLink_Terms":"OpenTable Terms of Use","GlobalHeaderLink_Help":"Help","GlobalHeaderLink_Home":"Home","GlobalHeaderLink_MyProfile":"My Profile","GlobalHeaderLink_SignIn":"Sign in","GlobalHeaderLink_SignOut":"Sign out","GlobalHeaderTagline":"Restaurant Reservations - Free &#8226; Instant &#8226; Confirmed","GoogleMaps_Region":"us","LogoImagePath":"/s/static/images/ot/opentable-logo.png","LogoImagePath_Concierge":"/s/static/images/ot/opentable-logo-concierge.png","PriceList2":"$$ ($30 and under)","PriceList3":"$$$ ($31 to $50)","PriceList4":"$$$$ ($50 and over)","PriceRange2":"$30 and under","PriceRange3":"$31 to $50","PriceRange4":"$50 and over","Recommended":"{0} Recommend","StarRatingText":"{0} star","StarRatingText_Plural":"{0} stars","TimeFormat":"h:mm a","DistanceUnit":"miles","DistanceUnit_Small":"mi","TimeFormatJS":"h:mm A","RestaurantsString":"Restaurants","DateAddedDateFormat":"MMMM D, YYYY","ReviewerDefaultName":"OpenTable Diner","PromoExpiredFallbackMessage":"[PromoName] has come and gone, but you can still dine at these great restaurants. Visit us next year to view a new restaurant list for [PromoName]. In the meantime, check out our other <a href=\"/start.aspx?m=[MetroID]\">[NumOfRestInMetro] [MetroShortName] restaurants</a> on the Opentable network."},
#     Home: {
#       Index: {"MileTitle":"mile","PageTitle":"Restaurant Reservation Availability","ReviewsComingSoon":"Reviews coming soon","SearchLoadingText":"Checking Availability"}
#     },
#     Shared: {
#       Common: {
#         BreadCrumbs: {"HomeNode":"Home","LastNode":"Restaurant availability"},
#         Filters: {"ChooseDistance":"Choose Distance","Distance":"miles","Expand_Link":"See all","Collapse_Link":"See less","MoreLink":"More","SeeAllOffers":"See all specials","ShowFilters":"Show filters","HideFilters":"Hide filters","Title":"Narrow results","Title_Cuisines":"Cuisine","Title_Locations":"Location","Title_OfferTypes":"Specials","Title_OnlyExactDateTime":"{0} Only","Title_OnlyOffers":"Only specials","Title_PopOnly":"1,000 Point Times","Title_Price":"Price","Title_Within":"Within","Title_JustAdded":"Newly Added Restaurants"},
#         LocationBar: {"ChangeLocation":"Change location"},
#         Modals: {"CancelButton":"Cancel","Location_AddressPlaceholderText":"Input city, address or zip","Location_AllMetroName":"All {0}","Location_ChangeLocationLink":"Change location","Location_DidYouMean":"Did you mean","Location_NoRadiusSelectedError":"<p class=\"location-error\">Please select a radius to search within</p>","Location_NoSearchResultsError":"<div class=\"list-wrapper\">\n    <span>Sorry, we were unable to find that location. Please check the address and retry.</span>\n    <p>Suggestions:</p>\n\n    <ul>\n        <li>Make sure all street and city names are spelled correctly.</li>\n        <li>Make sure your address includes a city and state.</li>\n        <li>Try entering a zip code.</li>\n    </ul>\n</div>","Location_NoSelectionError":"<p class=\"location-error\">Please search for a location or select from below</p>","Location_RadiusLabel":"Search within","Location_SearchLabel":"Enter City, or Zip","Location_SeeAllLocationsLink":"See All Cities and States","Location_SelectCity":"Or Select City","Location_Title_Area":"Neighborhoods","Location_Title_ChangeLocation":"Change Location","Offers_PopOfferTitle":"You get 1,000 Points","Offers_TooltipHeaderMultiple":"{0} specials available","Offers_TooltipHeaderSingle":"One special available","Price_Text":"The Price reflects the estimated price of a dinner for one with one drink and tip. Lunch usually costs 25% less.","Price_Title":"Price Legend","Restaurant_BookingMessage":"Reserve your table now","Restaurant_CrossStreet":"Cross Street","Restaurant_Cuisine":"Cuisine","Restaurant_Neighborhood":"Neighborhood","Restaurant_Parking":"Parking","Restaurant_Price":"Price","Restaurant_SpecialOffers":"Specials","SingleSearch_ReserveAt":"Reserve at {0}","SubmitButton":"Submit"},
#         Results: {"Header_Area":"Neighborhood","Header_Availability":"Availability (click time to reserve)","Header_Cuisine":"Cuisine","Header_Name":"Restaurant Name","Header_Name_Short":"Name","Header_Popularity":"Popularity","Header_Price":"Price","Header_Ratings":"Ratings","JustAdded_New":"New","NextAvailableButton":"Find next available","PopTitle":"{0} Restaurant with 1,000-Point times available","PopTitle_Plural":"{0} Restaurants with 1,000-Point times available","Reviews":"{0} review","ReviewsComingSoon":"Reviews coming soon","Reviews_Plural":"{0} reviews","SeeAllOffers":"See all specials","Timeslot1000Points":"1,000pts","Title_Availability":"{0} restaurant with availability","Title_Availability_Plural":"{0} restaurants with availability","Title_Promos":"{0} Restaurant","Title_NoAvailability":"{0} restaurant with no availability","Title_NoAvailability_Plural":"{0} restaurants with no availability","WithAvailabilityLink":"{0} additional restaurant with availability","WithAvailabilityLink_Plural":"{0} additional restaurants with availability","WithNoAvailabilityLink":"See additional restaurants with no availability","WithNoAvailabilityLink_Plural":"See additional restaurants with no availability","Header_Distance":"Distance","FeaturedPopTitle":"Restaurant with 1,000-Point times available","FeaturedPopTitle_Plural":"Restaurants with 1,000-Point times available","SidePopTitle":"Restaurant with 1,000-Point times","SidePopTitle_Plural":"Restaurants with 1,000-Point times","SeeAllAvailable":"See all available","Info_1000pt":"What are 1,000-point tables?","Header_Sorted_by":"Sorted by:","SeeAllPopRestaurantsFormat":"See all {0} restaurants with 1,000-Point times","Title_ResultsTotal":"{0} restaurant","Title_ResultsTotal_Plural":"{0} restaurants","Title_Promos_Plural":"{0} Restaurants"},
#         Strings: {"Button_FindATable":"Find a Table","DateTimePartySizeDateFormat":"ddd, MMMM D","Label_Next":"Next","Label_Previous":"Previous","SearchCoversLargeParty":"Larger Party","SearchCoversMultiple":"{0} people","SearchCoversSingular":"{0} person","SearchLabel_Date":"Date","SearchLabel_DateFormat":"mm/dd/yyyy","SearchLabel_Diners":"Party Size","SearchLabel_InvalidSearchMsg":"You have tried to select a time in the past. Please enter a valid date and time combination.","SearchLabel_Time":"Time"}
#       },
#       Search: {
#         Map: {"Navigation_Next":"Next","Navigation_Previous":"Prev","SearchWithin":"Only search for restaurants within","Title":"Showing nearest {0} restaurants","Title_Between":"Showing restaurants {0} - {1}","UserPinTitle":"Drag and drop me to search near a different area"},
#         Results: {"AboveMaxPartySize":"Your party size is larger than this restaurant's limit for online bookings.","BelowMinPartySize":"You have not entered the minimum party size for online bookings at this restaurant.","BlockedDay":"Online bookings are not available on this date at this restaurant.","EarlyCutoff":"Your requested date exceeds the minimum advance booking limit for this restaurant.","FilteredBy":"Filtered By","FilteredBy_Cuisine":"Cuisine","FilteredBy_Location":"Location","FilteredBy_OfferType":"Specials","FilteredBy_OnlyExactDateTime":"{0} only","FilteredBy_PopOnly":"1,000 Pt times","FilteredBy_Price":"Price","NotActive":"Online reservations for now have been suspended. If you would like to make a reservation please contact the restaurant directly.","NotFarEnoughInAdvance":"You must make bookings at least 5 minutes in advance of the time at this restaurant.","NoTimesExist":"No tables are available within 2.5 hours of your request.","Offline":"This restaurant is unable to confirm reservations online at the moment. Therefore, please contact the restaurant directly.","SameDayCutoff":"This Restaurant has a cut off time for same day reservations and this has now passed.","SeeAllOffers":"See all specials","TooFarInAdvance":"Your requested date exceeds the maximum advance booking limit for this restaurant.","BlockedTimesExist":"Please accept our apologies on behalf of {0}. Online bookings are not available on this date at this restaurant.","AltTag":"Photo of {0} Restaurant"},
#         Strings: {"NoSearchResults_MetroLink":"Return to the {0} homepage","NoSearchResults_MetroListLink":"Browse the list of all {0} restaurants","NoSearchResults_NoMatch_Message":"Unfortunately there are no OpenTable restaurants that meet all the criteria you specified.","NoSearchResults_NoMatch_Title":"We did not find a match for your search","NoSearchResults_Or":"or","NoSearchResults_OtherSuggestions":"Other suggestions","NoSearchResults_OtherSuggestionsMessage":"Or deselect any checkmarked box under \"Narrow results\" to broaden your search","NoSearchResults_StartOverButton":"Start over","NoSearchResults_UndoLastFilterButton":"Undo my last filter action"},
#         Tabs: {"List":"List","Map":"Map"}
#       },
#       Redesign: {
#         Filters: {"All_Cuisines":"All Cuisines","All_Locations":"All Locations","All_Offers":"All Specials","All_Prices":"All Prices","All_Tags":"All Top Rated","Label_Apply":"Apply","Label_Cancel":"Cancel","Label_FilterBy_Cuisine":"Filter by Cuisine","Label_FilterBy_OfferType":"Filter by Points & Specials","Label_FilterBy_Price":"Filter by Price","Label_FilterBy_Range":"Choose a Range","Label_FilterBy_Values":"You searched for:","Label_Sort":"Sort","Label_Sort_Distance":"Distance","Label_Sort_Name":"A-Z","Label_Sort_Popularity":"Most Popular","Label_Sort_Popularity_Mobile":"Popular","Label_Sort_Rating":"Highest Rated","Label_Sort_Rating_Mobile":"Rating","Times_Filter":"Times","Title_Cuisines":"Cuisine","Title_Featured":"Featured","Title_Filters":"Filters","Title_Locations":"Location","Title_Neighborhoods":"Neighborhoods","Title_OfferTypes":"Specials","Title_OnlyExactDateTime":"{0} Only","Title_PopOnly":"1,000 Point Times","Title_Price":"Price","Title_Range":"Range:","Title_RefineYourSearch":"Refine Your Search","Title_Regions":"Regions","Title_Tags":"Top Rated","Title_Time":"Time"},
#         Strings: {"CopyrightFormat":"Copyright &copy; {0} OpenTable, Inc. All rights reserved.","CurrencySymbol":"$","DefaultReviewerName":"OpenTable Diner","InterimLoader":"Finding tables...","Label_Next":"Next","Label_Previous":"Previous","Label_Sort":"Sort","Label_Sort_Name":"A-Z","Label_Sort_Popularity":"Most Popular","Label_Sort_Rating":"Highest Rated","Label_TopOffer":"Top special:","LearnMore":"Learn more","Less":"Less","MapFooterLink_Privacy":"Privacy Policy","MapFooterLink_Terms":"Terms of Use","More":"More","PointsText":"+ {0} pts","Recently_Viewed":"Recently viewed","Reserve_Dinner":"Reserve for Dinner","Reserve_Lunch":"Reserve for Lunch","Reserve_Now":"Reserve","SearchPlaceholder":"Location, Restaurant, or Cuisine","See_More":"See more","SimilarTo":"Similar to {0}","SorrySimilar":"Sorry, we could not find any similar restaurants for {0} at this time","Tags":"Top rated for ","TimeslotAvailability_Single":"Hurry, we only have 1 timeslot left!","TimeslotAvailability_Multiple":"Hurry, we only have {0} timeslots left!","TimeslotLegend_Offer":"Special","TimeslotLegend_Offers":"Specials","TimeslotAvailabile":"You're in luck! We still have 1 timeslot left.","TimeslotsAvailabile":"You're in luck! We still have {0} timeslots left."},
#         Results: {"Header_Area":"Neighborhood","Header_Availability":"Availability (click time to reserve)","Header_Cuisine":"Cuisine","Header_Name":"Restaurant Name","Header_Name_Short":"Name","Header_Popularity":"Popularity","Header_Price":"Price","Header_Ratings":"Ratings","ListingsMessage":"Unfortunately, this restaurant is not on the OpenTable reservation network. To see if they take reservations and have availability, you will need to call the restaurant directly or visit their website.","NextAvailableButton":"Find next available","PopTitle":"{0} table with 1,000-Point times available","PopTitle_Plural":"{0} tables with 1,000-Point times available","RequestReservation":"Request Reservation","Reviews":"{0} review","ReviewsComingSoon":"Reviews coming soon","Reviews_Plural":"{0} reviews","SeeAllOffers":"See all specials","Timeslot1000Points":"1,000pts","Title_Availability":"{0} table available for {1} on {2}, at {3}","Title_Availability_Plural":"{0} tables available for {1} on {2}, at {3}","Title_Exact_Match":"Exact Match","Title_Promos":"{0} Restaurant","Title_NoAvailability":"Tables with no availability for {1} on {2}, at {3}","Title_NoAvailability_Plural":"Tables with no availability for {1} on {2}, at {3}","Title_Regions_Description":"in {0}","WithAvailabilityLink":"{0} additional table available","WithAvailabilityLink_Plural":"{0} additional tables available","Header_Distance":"Distance","FeaturedPopTitle":"Restaurant with 1,000-Point times available","FeaturedPopTitle_Plural":"Restaurants with 1,000-Point times available","Header_Sorted_by":"Sorted by:","IncludeInterspercedAvailabilityLink":"Repeat this search showing omitted results","IncludeInterspercedAvailabilityText":"Some restaurants were not shown as they do not have availability matching your search criteria","About1000PointRestaurants":"About 1,000-Point Restaurants","Related_Searches":"Suggested searches","RestaurantsYouMayLike":"Restaurants you may also like","SingleSearchResults":"Search result for {0}","Title_IntersperseAvailability_Plural":"{0} tables for {1} on {2}, at {3}","Title_DateLessSearch":"{0} tables available","Title_DateLessSearch_Singular":"{0} table available","Title_Promos_Plural":"{0} Restaurants"},
#         NoResults: {"Heading":"We did not find a match for your search","OtherSuggestionsHeading":"Other suggestions","OtherSuggestionsMessage":"Or deselect any checked filters to broaden your search"}
#       },
#       PopRestaurantList: {
#         Strings: {"PageTitleFormat":"{0} restaurants dining rewards","PageDescription":"Earn free meals faster by making a 1,000 point reservation at one of these great restaurants. Once you reach 2,000 points you'll be able to redeem them for a $20 dining cheque!","PopScheduleHeading":"1,000 point tables","SearchBigHeadingFormat":"Make a 1,000-Point Reservation in {0}","PointsAboutText":"Get rewarded for dining.<br />Faster, with 1,000-point tables."}
#       },
#       MyLists: {
#         Strings: {"Favorites":{"Title":"Your Favorites","NoResultsTitleFormat":"Track Your All-Time Favorites","NoResultsSubTitle":"When it comes to food, it's okay to play favorites. You can add restaurants to your favorites list from any restaurant profile.","NoResultsActionButton":"Find Restaurants"},"DiningHistory":{"Title":"Your Dining History","NoResultsTitleFormat":"You don’t have any reservations yet","NoResultsSubTitle":"Start booking today and your past reservations will display here to quickly find again!","NoResultsActionButton":"Find a Table"},"WishList":{"Title":"Your List","NoResultsTitleFormat":"Create Your List","NoResultsSubTitle":"Recommendations by friends & family? Expert reviews? You can add restaurants to your list from any restaurant profile.","NoResultsActionButton":"Find Restaurants"}}
#       }
#     }
#   };
# </script><script src="//media.otstatic.com/search-result-node/js/generated/bundle_views_redesign.a824f354.js"></script> <script id="marketing-data-layer-scripts">
#     var todaysDate = new Date();
#     window.OT = window.OT || {};
#     window.OT.MarketingDataLayer = {"language":"en-US","page_name":"search","time_search":"7:00:00 PM","date_search":"2016-12-22T19:00:00+00:00","searchgeo_longlat":"-77.078333,38.905063","logged_in_status":"logged_out","user_primary_metro_id":9,"user_origin":9};
#     window.OT.MarketingDataLayer.current_date = todaysDate.toISOString();
#     window.OT.MarketingDataLayer.day_type = todaysDate.getDay() % 6 ? 'weekday' : 'weekend';
#   </script> <script id="srs-scripts">window.OT = window.OT || {};
# window.OT.SRS = window.OT.SRS || {};
#
# window.OT.SRS.calendarStartsSunday = true;
# window.OT.SRS.dateFormatJS = "mmm d, yyyy";
# window.OT.SRS.domainId = 1;
# window.OT.SRS.domains = {"1":"http://www.opentable.com/","2":"http://www.opentable.jp/","3":"http://www.opentable.de/","6":"http://www.opentable.com.mx/","11":"https://www.opentable.ie/","70":"http://www.opentable.co.uk/","71":"https://www.opentable.com.au/"};
# window.OT.SRS.exactTarget = true;
# window.OT.SRS.location = "//components.otstatic.com/components/js/1.0.80/";
# window.OT.SRS.omniture = {"account":"otcom","server":"o.opentable.com","secureServer":"so.opentable.com"};
# window.OT.SRS.secure_domain = "www.opentable.com";
# window.OT.SRS.srsUrl = "//na-srs.opentable.com";
# window.OT.SRS.timeFormatJS = "h:mm A";
# window.OT.SRS.today = "Today";
# window.OT.SRS.tomorrow = "Tomorrow";
# </script><script crossorigin="anonymous" src="//components.otstatic.com/components/js/1.0.80/min/bundle_common.js"></script><noscript><img alt="" border="0" height="1" src="https://so.opentable.com/b/ss/otcom/1/H.22.1--NS/0" width="1"/><iframe frameborder="0" height="1" marginheight="0" marginwidth="0" scrolling="no" src="//s.thebrighttag.com/iframe?c=d0upCKz" width="1"></iframe></noscript><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["js"]="1.0.80";</script> <script src="//media.otstatic.com/search-result-node/js/generated/bundle_common_redesign.4530af46.js"></script>
# <script src="//media.otstatic.com/search-result-node/js/generated/bundle_redesign.853a0514.js"></script>
# <script src="//media.otstatic.com/search-autocomplete-client/js/one-box-search-10.5.0.min.js"></script>
# <!-- Experiments -->
# <script>
#
#
#
#   OT.Common.init();
#   OT.Redesign.init();
#   OT.Autocomplete.init();
#   OT.BestAnalytics.logRequest();
#
#
# </script>
# <script>
#     OT.Common.Analytics.init(
#       jQuery.extend(
#         {"channel":"Washington, D.C. Area","charSet":"UTF-8","eVar16":"ratingssearchuser","eVar24":"All","eVar28":"7:00 pm","eVar30":100,"eVar34":"Logged Out","eVar36":"anonymous","eVar39":"Washington, D.C. Area","eVar41":"MetroDTP","eVar43":"restaurantlist","eVar47":"listsearcher","eVar50":"restaurantlist","eVar57":"WebRedesign_New","eVar72":"tt_no_offers_searchresults","eVar74":"new_architecture_newdesign","events":"event2,event23","pageName":"restaurantlist","prop1":"Washington, D.C. Area:search","prop24":"All","prop25":"2016-12-22T19:00:00.000Z","prop28":"7:00 pm","prop2":"Washington, D.C. Area:search:multi","prop30":100,"prop33":"All","prop35":"searchopentables","prop38":"restaurantlist","prop45":"nofpopshown","prop46":"ratingsdisplayed","prop58":"","prop7":"Logged Out"},
#         { prop54: s_getLoadTime() }
#       )
#     );
#
#     </script></body></html>

# %% [markdown]
# What do you notice? Why is this happening?

# %% [markdown]
# ## Enter Selenium
#
# Selenium is a headless browser. That means it enables us to mock human browsing behavior -- even waiting for JavaScript elements to load.
#
# If you do not already have Selenium installed, you can do so via pip. Simply: `pip install selenium`

# %%
# import
from selenium import webdriver

# %% [markdown]
# Selenium requires us to determine a default browser to run. I'm going to opt for Firefox, but Chromium is also a very common choice. http://selenium-python.readthedocs.io/faq.html

# %%
# STOP
# what is going to happen when I run the next cell?

# %%
# create a driver called Firefox
driver = webdriver.Firefox()

# %% [markdown]
# Pretty crazy, right? Let's close that driver.

# %%
# close it
driver.close()

# %%
# let's boot it up, and visit a URL of our choice
driver = webdriver.Firefox()
driver.get("http://www.python.org")

# %% [markdown]
# Awesome. Now we're getting somewhere: programmatically controlling our browser like a human.

# %%
driver = webdriver.Firefox()
driver.get("http://www.python.org")

# %% [markdown]
# Let's return to our problem at hand. We need to visit the OpenTable listing for DC. Once there, we need to get the html to load. In the next cell, prove you can programmatically visit the page.

# %%
# visit our OpenTable page
driver = webdriver.Firefox()
driver.get("http://www.opentable.com/washington-dc-restaurant-listings")
# always good to check we've got the page we think we do
assert "OpenTable" in driver.title

# %% [markdown]
# Now, to resolve our JavaScript problem, there's a few things we can do. What I'll do in this case is request that the page load, wait one second, and then I'm going to grab the source html from the page. Because the page should believe I'm visiting from a live connection on a browser client, the JavaScript should render to be a part of the page source. I can then grab the page source.

# %%
# import sleep
from time import sleep

# %%
# visit our relevant page
driver = webdriver.Firefox()
driver.get("http://www.opentable.com/washington-dc-restaurant-listings")
# wait one second
sleep(1)
#grab the page source
html = driver.page_source

# %% [raw]
# Pop quiz: what do we need to do with this html?

# %%
# BeautifulSoup it!
html = BeautifulSoup(html)

# %% [markdown]
# Now, let's return to our earlier problem: how do we locate bookings on the page?

# %%
# print out the number bookings for all restaurants
print html.find_all('div', {'class':'booking'})
# Out:
# [<div class="booking"><span class="tadpole"></span>Booked 26 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 204 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 139 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 39 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 134 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 65 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 4 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 45 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 159 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 109 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 36 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 466 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 117 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 45 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 286 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 86 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 300 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 25 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 65 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 55 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 66 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 257 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 203 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 58 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 73 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 41 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 146 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>, <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>, <div class="booking"><span class="tadpole">< ...

# %%
# now print out each booking for the listings using a loop
for booking in html.find_all('div', {'class':'booking'}):
    print booking
# Out:
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 204 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 139 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 39 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 134 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 65 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 4 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 45 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 159 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 109 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 36 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 466 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 117 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 45 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 286 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 86 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 300 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 25 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 65 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 55 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 66 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 257 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 203 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 58 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 73 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 41 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 146 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 59 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 283 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 45 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 61 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 34 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 69 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 16 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 91 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 16 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 68 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 58 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 63 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 72 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 46 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 36 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 47 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 68 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 108 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 16 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 60 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 46 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 92 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 71 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 5 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 61 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 181 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 48 times today</div>

# %% [markdown]
# Let's grab just the text of each of these entries.

# %%
# do the same as above, but grabbing only the text content
for booking in html.find_all('div', {'class':'booking'}):
    print booking.text
# Out:
# Booked 26 times today
# Booked 20 times today
# Booked 6 times today
# Booked 204 times today
# Booked 139 times today
# Booked 39 times today
# Booked 134 times today
# Booked 65 times today
# Booked 4 times today
# Booked 9 times today
# Booked 27 times today
# Booked 45 times today
# Booked 159 times today
# Booked 109 times today
# Booked 36 times today
# Booked 20 times today
# Booked 40 times today
# Booked 23 times today
# Booked 7 times today
# Booked 466 times today
# Booked 50 times today
# Booked 117 times today
# Booked 45 times today
# Booked 286 times today
# Booked 86 times today
# Booked 300 times today
# Booked 23 times today
# Booked 24 times today
# Booked 25 times today
# Booked 35 times today
# Booked 65 times today
# Booked 55 times today
# Booked 66 times today
# Booked 257 times today
# Booked 9 times today
# Booked 12 times today
# Booked 28 times today
# Booked 22 times today
# Booked 203 times today
# Booked 26 times today
# Booked 58 times today
# Booked 26 times today
# Booked 73 times today
# Booked 41 times today
# Booked 146 times today
# Booked 7 times today
# Booked 26 times today
# Booked 19 times today
# Booked 31 times today
# Booked 8 times today
# Booked 59 times today
# Booked 283 times today
# Booked 45 times today
# Booked 61 times today
# Booked 22 times today
# Booked 34 times today
# Booked 69 times today
# Booked 16 times today
# Booked 91 times today
# Booked 12 times today
# Booked 12 times today
# Booked 16 times today
# Booked 28 times today
# Booked 9 times today
# Booked 68 times today
# Booked 58 times today
# Booked 35 times today
# Booked 23 times today
# Booked 63 times today
# Booked 27 times today
# Booked 72 times today
# Booked 7 times today
# Booked 8 times today
# Booked 14 times today
# Booked 19 times today
# Booked 46 times today
# Booked 36 times today
# Booked 47 times today
# Booked 68 times today
# Booked 11 times today
# Booked 24 times today
# Booked 108 times today
# Booked 16 times today
# Booked 60 times today
# Booked 46 times today
# Booked 22 times today
# Booked 92 times today
# Booked 71 times today
# Booked 6 times today
# Booked 15 times today
# Booked 5 times today
# Booked 61 times today
# Booked 181 times today
# Booked 48 times today

# %% [markdown]
# We've succeeded!
#
# But we can clean this up a little bit. We're going to use regular expressions (regex) to grab only the digits that are available in each of the text.
#
# The best way to get good at regex is to, well, just keep trying and testing: http://pythex.org/

# %%
# import regex
import re

# %% [markdown]
# Given we haven't covered regex, I'll show you how to use the search function to match any given digit.

# %%
# for each entry, grab the text
for booking in html.find_all('div', {'class':'booking'}):
    # match all digits
    match = re.search(r'\d+', booking.text)
    # print if found
    if match:
        print match.group()
    # otherwise pass
    else:
        pass
# Out:
# 26
# 20
# 6
# 204
# 139
# 39
# 134
# 65
# 4
# 9
# 27
# 45
# 159
# 109
# 36
# 20
# 40
# 23
# 7
# 466
# 50
# 117
# 45
# 286
# 86
# 300
# 23
# 24
# 25
# 35
# 65
# 55
# 66
# 257
# 9
# 12
# 28
# 22
# 203
# 26
# 58
# 26
# 73
# 41
# 146
# 7
# 26
# 19
# 31
# 8
# 59
# 283
# 45
# 61
# 22
# 34
# 69
# 16
# 91
# 12
# 12
# 16
# 28
# 9
# 68
# 58
# 35
# 23
# 63
# 27
# 72
# 7
# 8
# 14
# 19
# 46
# 36
# 47
# 68
# 11
# 24
# 108
# 16
# 60
# 46
# 22
# 92
# 71
# 6
# 15
# 5
# 61
# 181
# 48

# %% [markdown]
# Before we demonstrate all the other amazing things about headless browsers, let's finish up collecting the data we want from this current example. Do you suppose the html parsing we wrote above will still work on the page source we've grabbed from our headless browser?

# %% [markdown]
# To be most efficient, we want to only do a single loop for each entry on the page. That means we want to find what element all of other other elements (name, location, price, bookings) is housed within. Where on the page is each entry located?

# %%
# print out all entries
print html.find_all('div', {'class':'result content-section-list-row cf with-times'})
# Out:
# [<div class="result content-section-list-row cf with-times" data-id="0" data-index="1" data-lat="38.7886940" data-lon="-77.0190220" data-offers="" data-rid="341935"><div class="rest-row with-image"> <div class="rest-row-image"><div class="favorite-box"><a class="favorite-button row-hover" data-rid="341935" href="javascript:void(0)"></a></div> <a href="/r/voltaggio-brothers-steak-house-mgm-national-harbor" target="_blank"><img alt="photo of voltaggio brothers steak house - mgm national harbor restaurant" class="lazy rest-image loaded" data-src="//resizer.otstatic.com/v2/profiles/legacy/341935.jpg" src="//resizer.otstatic.com/v2/profiles/legacy/341935.jpg"/></a></div> <div class="rest-row-info"> <a class="rest-row-name rest-name just-added" href="/r/voltaggio-brothers-steak-house-mgm-national-harbor" target="_blank"> <span class="listIndex">1.</span> <span class="rest-row-name-text">Voltaggio Brothers Steak House - MGM National Harbor</span> <span class="new-restaurant-tag">New</span> </a> <div class="rest-row-review"> <div class="star-rating"><div class="star-wrapper small"><div class="all-stars"></div><div class="all-stars filled" style="width: 90%;"></div></div> <a class="review-link" href="/r/voltaggio-brothers-steak-house-mgm-national-harbor#reviews" target="_blank"><span class="star-rating-text">(11)</span><span class="star-rating-text--review-text">11 reviews</span></a> <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">92% Recommend</span></span> </div> </div> <div class="rest-row-pricing"> <i>  $    $    $    $  </i> </div> <div class="rest-row-meta rest-row-meta-grid"> <span class="rest-row-meta--cuisine rest-row-meta-text">Steakhouse</span> <span class="rest-row-meta--location rest-row-meta-text">Oxon Hill</span><div class="ab-testing-hide"> , region</div> </div> <div class="message-alerts"><div class="booking"><span class="tadpole"></span>Booked 26 times today</div> </div> <div class="rest-row-times-cont"> <a class="button minimal" href="/r/voltaggio-brothers-steak-house-mgm-national-harbor">Find next available</a> <p class="not-available-message"> No tables are available within 2.5 hours of your 7:00 PM request.</p> </div> </div></div> </div>, <div class="result content-section-list-row cf with-times" data-id="1" data-index="2" data-lat="38.8961370" data-lon="-77.0239920" data-offers="" data-rid="148087"><div class="rest-row with-image"> <div class="rest-row-image"><div class="favorite-box"><a class="favorite-button row-hover" data-rid="148087" href="javascript:void(0)"></a></div> <a href="/barmini-by-jose-andres" target="_blank"><img alt="photo of barmini by josé andrés restaurant" class="lazy rest-image loaded" data-src="//resizer.otstatic.com/v2/profiles/legacy/148087.jpg" src="//resizer.otstatic.com/v2/profiles/legacy/148087.jpg"/></a></div> <div class="rest-row-info"> <a class="rest-row-name rest-name " href="/barmini-by-jose-andres" target="_blank"> <span class="listIndex">2.</span> <span class="rest-row-name-text">barmini by José Andrés</span> </a> <div class="rest-row-review"> <div class="star-rating"><div class="star-wrapper small"><div class="all-stars"></div><div class="all-stars filled" style="width: 96%;"></div></div> <a class="review-link" href="/barmini-by-jose-andres#reviews" target="_blank"><span class="star-rating-text">(292)</span><span class="star-rating-text--review-text">292 reviews</span></a> <span class="recommended-container"><span class="bullet">•</span><span class="thumbs-up"></span> <span class="recommended">93% Recommend</span></span> </div> </div> <div class="rest-row-pricing"> <i>  $    $    $    </i>   $        </div> <div class="rest-row-meta rest-row-meta-grid"> <span class="rest-row-meta--cuisine rest-row-meta-text">Bar / Lounge / Bottle Service</span> <span class="rest-row-meta--location rest-row-meta-text">Penn Quarter</span><div class="ab-testing-hide"> , region</div> </div> <div class="message-alerts"><div  ...

# %% [markdown]
# Look over the page. Does every single entry have each element we're seeking?
# > I did this previously. I know for a fact that not every element has a number of recent bookings. That's probably exactly why OpenTable houses this in JavaScript: they want to continously update the number of bookings with the most relevant number of values.

# %%
# what happens when a booking is not available?
# print out each booking entry, using the identification code we wrote above
for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
    print entry.find('div', {'class':'booking'})
# Out:
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 204 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 139 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 39 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 134 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 65 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 4 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# None
# <div class="booking"><span class="tadpole"></span>Booked 45 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 159 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 109 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 36 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 466 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 117 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 45 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 286 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 86 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 300 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 25 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 65 times today</div>
# None
# <div class="booking"><span class="tadpole"></span>Booked 55 times today</div>
# None
# <div class="booking"><span class="tadpole"></span>Booked 66 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 257 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# None
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 203 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 58 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 73 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 41 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 146 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 59 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 283 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 45 times today</div>
# None
# <div class="booking"><span class="tadpole"></span>Booked 61 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 34 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 69 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 16 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 91 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 16 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 68 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 58 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 63 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 72 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# None
# <div class="booking"><span class="tadpole"></span>Booked 46 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 36 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 47 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 68 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 108 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 16 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 60 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 46 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 22 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 92 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 71 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 5 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 61 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 181 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 48 times today</div>

# %% [markdown]
# What do you notice takes the place when booking is not found?
#
# Thus, we will use exceptions. Here's a demo:

# %%
# if we find the element we want, we print it. Otherwise, we print 'ZERO'
for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
    try:
        print entry.find('div', {'class':'booking'}).text
    except:
        print 'ZERO'
# Out:
# Booked 26 times today
# Booked 20 times today
# Booked 6 times today
# Booked 204 times today
# Booked 139 times today
# Booked 39 times today
# Booked 134 times today
# Booked 65 times today
# Booked 4 times today
# Booked 9 times today
# Booked 27 times today
# ZERO
# Booked 45 times today
# Booked 159 times today
# Booked 109 times today
# Booked 36 times today
# Booked 20 times today
# Booked 40 times today
# Booked 23 times today
# Booked 7 times today
# Booked 466 times today
# Booked 50 times today
# Booked 117 times today
# Booked 45 times today
# Booked 286 times today
# Booked 86 times today
# Booked 300 times today
# Booked 23 times today
# Booked 24 times today
# Booked 25 times today
# Booked 35 times today
# Booked 65 times today
# ZERO
# Booked 55 times today
# ZERO
# Booked 66 times today
# Booked 257 times today
# Booked 9 times today
# Booked 12 times today
# ZERO
# Booked 28 times today
# Booked 22 times today
# Booked 203 times today
# Booked 26 times today
# Booked 58 times today
# Booked 26 times today
# Booked 73 times today
# Booked 41 times today
# Booked 146 times today
# Booked 7 times today
# Booked 26 times today
# Booked 19 times today
# Booked 31 times today
# Booked 8 times today
# Booked 59 times today
# Booked 283 times today
# Booked 45 times today
# ZERO
# Booked 61 times today
# Booked 22 times today
# Booked 34 times today
# Booked 69 times today
# Booked 16 times today
# Booked 91 times today
# Booked 12 times today
# Booked 12 times today
# Booked 16 times today
# Booked 28 times today
# Booked 9 times today
# Booked 68 times today
# Booked 58 times today
# Booked 35 times today
# Booked 23 times today
# Booked 63 times today
# Booked 27 times today
# Booked 72 times today
# Booked 7 times today
# Booked 8 times today
# Booked 14 times today
# Booked 19 times today
# ZERO
# Booked 46 times today
# Booked 36 times today
# Booked 47 times today
# Booked 68 times today
# Booked 11 times today
# Booked 24 times today
# Booked 108 times today
# Booked 16 times today
# Booked 60 times today
# Booked 46 times today
# Booked 22 times today
# Booked 92 times today
# Booked 71 times today
# Booked 6 times today
# Booked 15 times today
# Booked 5 times today
# Booked 61 times today
# Booked 181 times today
# Booked 48 times today

# %% [markdown]
# From previously completing this, I know all other elements WILL be returned. That means we do not have to create exceptions for them.
#
# However, the onus is on you to now put all the pieces together.
#
# Loop through each entry. For each entry, grab the relevant information we want (name, location, price, bookings). Produce a dataframe with the columns "name","location","price","bookings" that contains the 100 entries we would like.

# %%
# I'm going to create my empty df first
import pandas as pd
dc_eats = pd.DataFrame(columns=["name","location","price","bookings"])

# %%
# loop through each entry
for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
    # grab the name
    name = entry.find('span', {'class': 'rest-row-name-text'}).text
    # grab the location
    location = entry.find('span', {'class': 'rest-row-meta--location rest-row-meta-text'}).renderContents()
    # grab the price
    price = entry.find('div', {'class': 'rest-row-pricing'}).find('i').renderContents().count('$')
    # try to find the number of bookings
    try:
        temp = entry.find('div', {'class':'booking'}).text
        match = re.search(r'\d+', temp)
        if match:
            bookings = match.group()
    except:
        bookings = 'NA'
    # add to df
    dc_eats.loc[len(dc_eats)]=[name, location, price, bookings]

# %%
# check out our work
dc_eats.head()
# Out:
#                                                 name      location  price  \
# 0  Voltaggio Brothers Steak House - MGM National ...     Oxon Hill    4.0
# 1                             barmini by José Andrés  Penn Quarter    3.0
# 2          Fish by Jose Andres - MGM National Harbor     Oxon Hill    4.0
# 3                                       Le Diplomate  Logan Circle    3.0
# 4                                             Rasika  Penn Quarter    3.0
#
#   bookings
# 0       26
# 1       20
# 2        6
# 3      204
# 4      139

# %% [markdown]
# Awesome! We succeeded.
#
# Now, let's explore some of the other functionality of a webdriver. We've barely scratched the surface.

# %%
# we can send keys as well
# import
from selenium.webdriver.common.keys import Keys

# %%
# open Firefox
driver = webdriver.Firefox()
# visit Python
driver.get("http://www.python.org")
# verify we're in the right place
assert "Python" in driver.title

# %%
# find the search position
elem = driver.find_element_by_name("q")
# clear it
elem.clear()
# type in pycon
elem.send_keys("pycon")

# %%
# send those keys
elem.send_keys(Keys.RETURN)
# no results
assert "No results found." not in driver.page_source

# %%
# close
driver.close()

# %%
# all at once:
driver = webdriver.Firefox()
driver.get("http://www.python.org")
assert "Python" in driver.title
elem = driver.find_element_by_name("q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
assert "No results found." not in driver.page_source
driver.close()

# %% [markdown]
# The above example (and many others) are available in the Selenium docs: http://selenium-python.readthedocs.io/getting-started.html
#
# What is especially important is exploring functionality like locating elements: http://selenium-python.readthedocs.io/locating-elements.html#locating-elements
#
# FAQ:
# http://selenium-python.readthedocs.io/faq.html
