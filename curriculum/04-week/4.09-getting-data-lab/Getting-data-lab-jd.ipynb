# %% [markdown]
# ## Automated Data Collection Lab
#
# For this lab, you are asked to produce a list of all of Lincoln's quotes available on this page: http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1 Use the requests and BeautifulSoup libraries in Python.
#
# For a bonus, collect all the quotes from each page available on Successories.

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/'
quotes = []                      

for page_num in range(1,45):
    url_page = url + str(page_num)
    page = requests.get(url_page).content
    page = BeautifulSoup(page)
    for tag in page.find_all(name='div', attrs={'class':'quote'}):
        for quote in tag.find(name='a'):
            quotes.append(quote)

len(quotes)
# Out:
# //anaconda/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file //anaconda/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# 440

# %%
page
# Out:
# <!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml">\n<head>\n<title>Abraham Lincoln Quotes |  Successories | Quote Database | Motivational Posters | Quotes 431-440</title><meta content="The largest collection of Abraham Lincoln quotes. Successories iQuote Quote database has gathered 440 of Abraham Lincoln quotes. Search Abraham Lincoln quotes. Quotes 431-440 Put quotes on Motivational Posters and Awards Recognition." name="description"/><meta content="en-us" http-equiv="Content-Language"/>\n<meta content="Employee Gifts, Awards Recognition, Motivational Posters" name="classification"/><meta content="index,follow" name="robots"/>\n<meta content="uJjzLV_M66fPgenvGXEETRewzeCLlM8tyfIn7UYw9zQ" name="google-site-verification"/><meta content="B015DAC7E38DC29941EBB997DC79B420" name="msvalidate.01"/>\n<meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width; initial-scale=1.0; maximum-scale=1.0; user-scalable=0;" name="viewport"/>\n<base href="http://www.successories.com/"/>\n<link href="http://www.successories.com/css/combined.php?1491085203" rel="stylesheet" type="text/css"/><!--[if IE 8]><link href="http://www.successories.com/css/ie8.css?1485614893" rel="stylesheet" type="text/css" /><![endif]--><link href="http://www.successories.com/css/quotedb.css?1491085203" rel="stylesheet" type="text/css"/>\n<link href="http://www.successories.com/images/favicon.ico?1485614893" rel="shortcut icon"/>\n<link href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/44" rel="canonical"/><script src="http://www.successories.com/framework/js/combined.php?1487792787" type="text/javascript"></script>\n<link href="http://www.successories.com/css/quotedb.css?1491085203" rel="stylesheet" type="text/css"/>\n<script type="text/javascript">(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create','UA-1071924-1','successories.com');ga('require','displayfeatures');ga('require','GTM-NW53TFM');ga('send','pageview');</script>\n</head>\n<body style="margin:0; padding:0; color:#333; background-color:#FFFFFF;">\n<div class="wrapper" style="min-height: 100%; height: auto; height: 100%;">\n<div id="header">\n<div id="header-container-outter">\n<div id="header-container">\n<div id="logo"><a href="http://www.successories.com/"><img alt="Successories Employee Motivational Gifts and Awards" class="headercart" src="images/gfx-header/Successories-Employee-Motivational-Gifts-and-Awards.png"/></a></div>\n<a class="header-icon" href="http://www.successories.com/cart" id="header_cart_snapshot"><img src="images/gfx-header/cart2.png"/><span class="carttotal" id="header-cart-snapshot">0 items</span></a>\n<a class="header-icon" href="https://www.successories.com/account/favorite-products" id="header_favorites_snapshot"><img class="header-favorite" src="images/gfx-header/favorite.png"/><span>Account</span></a>\n<div class="header-icon mobile-sm-hide" id="header_phone_number" style="display:none"><strong>1-800-535-2773</strong><br/><span>Call Us 9am-5pm ET</span></div>\n<a class="mobile-sm-show header-icon" href="tel:18005352773" id="header-global-call-mobile"><img onclick="" src="images/gfx-header/call-mobile.jpg"/></a>\n<a class="header-icon" id="header_menu_mobile-show" onclick="Activa.DOM.addClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-hide'); Activa.DOM.hideID('header_menu_mobile-show'); Activa.DOM.hideID('header-global-search-mobile');"><img class="header-menu" src="images/gfx-header/menu-mobile.jpg"/></a>\n<a class="header-icon" id="header_menu_mobile-hide" onclick="Activa.DOM.removeClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-show'); Activa.DOM.hideID('header_menu_mobile-hide'); Activa.DOM.hideID('head ...
